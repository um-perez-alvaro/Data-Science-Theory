# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Problem 4: Violent Crime Rates by US State

# %% [markdown]
# The *USArrests* dataset contains statistics, in arrests per 100,000 residents for assault, murder, and rape in each of the 50 US states in 1973.
# The percentage of the population living in urban areas is also given.
# The aim of the dataset is to see if there is any dependency between the state been acquired and the arrest history.

# %%
# load the data
url = 'https://raw.githubusercontent.com/um-perez-alvaro/Data-Science-Theory/master/Data/USArrests.csv'
data = pd.read_csv(url, index_col=0)
data
# Out:
#                 Murder  Assault  UrbanPop  Rape
# Alabama           13.2      236        58  21.2
# Alaska            10.0      263        48  44.5
# Arizona            8.1      294        80  31.0
# Arkansas           8.8      190        50  19.5
# California         9.0      276        91  40.6
# Colorado           7.9      204        78  38.7
# Connecticut        3.3      110        77  11.1
# Delaware           5.9      238        72  15.8
# Florida           15.4      335        80  31.9
# Georgia           17.4      211        60  25.8
# Hawaii             5.3       46        83  20.2
# Idaho              2.6      120        54  14.2
# Illinois          10.4      249        83  24.0
# Indiana            7.2      113        65  21.0
# Iowa               2.2       56        57  11.3
# Kansas             6.0      115        66  18.0
# Kentucky           9.7      109        52  16.3
# Louisiana         15.4      249        66  22.2
# Maine              2.1       83        51   7.8
# ...

# %% [markdown]
# **Data Description**
#
# | Feature | Description |
# | :- | -: |
# | Murder | Murder arrests (per 100,000) |
# | Assault |	Assault arrests (per 100,000) |
# | UrbanPop | Percent urban population |
# | Rape | Rape arrests (per 100,000) |

# %% [markdown]
# ## Part 1: K-means

# %% [markdown]
# Cluster the states using k-means, and ensure that you have a good number of clusters (using the "elbow" method, for example).
# Scale the data before running the k-means method.

# %%
# RUN ME; k is the  optimal number of clusters (from the elbow method)
for i in range(k):
    print('cluster '+str(i))
    print(data.iloc[clusters==i])
    print('---------------------------------------------')
# Out:
# cluster 0
#                Murder  Assault  UrbanPop  Rape
# Arkansas          8.8      190        50  19.5
# Connecticut       3.3      110        77  11.1
# Delaware          5.9      238        72  15.8
# Hawaii            5.3       46        83  20.2
# Idaho             2.6      120        54  14.2
# Indiana           7.2      113        65  21.0
# Iowa              2.2       56        57  11.3
# Kansas            6.0      115        66  18.0
# Kentucky          9.7      109        52  16.3
# Maine             2.1       83        51   7.8
# Massachusetts     4.4      149        85  16.3
# Minnesota         2.7       72        66  14.9
# Montana           6.0      109        53  16.4
# Nebraska          4.3      102        62  16.5
# New Hampshire     2.1       57        56   9.5
# New Jersey        7.4      159        89  18.8
# North Dakota      0.8       45        44   7.3
# Ohio              7.3      120        75  21.4
# Oklahoma          6.6      151        68  20.0
# ...

# %% [markdown]
# ## Part 2: Visualization of the k-means clusters

# %% [markdown]
# USArrest data are four dimensional.
# To be able to visualize the clusters, we need to project the data into a 2D space.

# %% [markdown]
# The dimensionality reduction technique we will be using is called the **Principal Component Analysis (PCA).**
# It is a powerful technique that arises from linear algebra and probability theory.
# PCA is used to decompose a multivariate dataset in a set of successive orthogonal components that explain a maximum amount of the variance of the data.

# %%
# RUN ME

# apply pca
from sklearn.decomposition import PCA
X_reduced = PCA(n_components=2).fit_transform(X)

# plot clusters
plt.figure(figsize=(15,7))
for i in range(k):
    plt.plot(X_reduced[clusters==i,0], X_reduced[clusters==i,1],'o', label='cluster '+str(i))
plt.legend(fontsize=15)
    
# annotate the plot
states = list(data.index)
for i in range(len(X_reduced)):
    x,y = X_reduced[i]
    state = str(states[i])
    plt.annotate(state, (x+0.01,y+0.01))
