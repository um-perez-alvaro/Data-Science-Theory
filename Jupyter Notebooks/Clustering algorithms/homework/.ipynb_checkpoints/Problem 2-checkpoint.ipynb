# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.metrics import pairwise_distances

# %% [markdown]
# # Problem 2: Clustering for Color Segmentation

# %% [markdown]
# In this problem, you will learn how to use clustering techniques to segment images based on their color.

# %% [markdown]
# Color segmentation involves partitioning an image into multiple segments, such that all pixels belonging to the same segment are assigned the same color.

# %% [markdown]
# This technique finds its use in various applications. In this homework assignment, you will use color segmentation to compress an image (Part 1), and identify regions of interest (Parts 2 and 3)."

# %% [markdown]
# ## Part 1: Image compression

# %% [markdown]
# In a colored image, each pixel has a size of 3 bytes (RGB), where each color (red/green/blue) can have intensity values ranging from 0 to 255. Therefore, the total number of colors that can be represented is 256 x 256 x 256 = 16,777,216. In this section, you will utilize k-means to reduce the number of colors required to represent a colored digital image, which is also known as color quantization."

# %%
# load the image
from matplotlib.image import imread
url = 'https://raw.githubusercontent.com/um-perez-alvaro/Data-Science-Theory/master/Data/St_Basil_Cathedral.png'
image = imread(url)[:,:,0:3]
# Out:
# C:\Users\javier.perez-alvaro\AppData\Local\Temp\ipykernel_4212\3812503751.py:4: MatplotlibDeprecationWarning: Directly reading images from URLs is deprecated since 3.4 and will no longer be supported two minor releases later. Please open the URL for reading and pass the result to Pillow, e.g. with ``np.array(PIL.Image.open(urllib.request.urlopen(url)))``.
#   image = imread(url)[:,:,0:3]

# %% [markdown]
# The image is represented as a three-dimensional array.

# %%
image.shape
# Out:
# (600, 394, 3)

# %% [markdown]
# The first dimension's size corresponds to the height, the second dimension's size corresponds to the width, and the third dimension's size corresponds to the number of color channels, namely red, green, and blue (RGB).

# %%
# display the  image
plt.figure(figsize=(17,7))
plt.imshow(image)
plt.axis('off')
plt.savefig('image.png')

# %% [markdown]
# The following code cell reshapes the array to obtain a lengthy list of RGB colors. The resulting matrix X has a row for every pixel, amounting to a total of 600x394=236,400 rows (pixels).

# %%
X = image.reshape(-1,3)
X.shape
# Out:
# (236400, 3)

# %% [markdown]
# Cluster the pixels (i.e., rows of X) using the k-means algorithm.
# Then, replace each pixel (i.e., each row of X) with its respective cluster mean.
# Plot the resulting image for k=2, 4, 6, 8, 10, and 12.

# %% [markdown]
# ## Part 2: Identifying regions of interest

# %% [markdown]
# In this section, you will explore how color segmentation can be utilized to identify and extract regions of interest from an image, which can help in various image analysis tasks.

# %%
# load the image
url = 'https://raw.githubusercontent.com/um-perez-alvaro/Data-Science-Theory/master/Data/cancer_cells.png'
image = imread(url)[:,:,0:3]
# Out:
# C:\Users\javier.perez-alvaro\AppData\Local\Temp\ipykernel_4212\3434805461.py:3: MatplotlibDeprecationWarning: Directly reading images from URLs is deprecated since 3.4 and will no longer be supported two minor releases later. Please open the URL for reading and pass the result to Pillow, e.g. with ``np.array(PIL.Image.open(urllib.request.urlopen(url)))``.
#   image = imread(url)[:,:,0:3]

# %% [markdown]
# The file cancer_cells.png is a digital image of a small section of a breast cancer tumor mass.

# %%
# display the image
plt.figure(figsize=(10,5))
plt.imshow(image)
plt.axis('off')
plt.savefig('image.png')

# %%
image.shape
# Out:
# (120, 192, 3)

# %%
X = image.reshape(-1,3)
X.shape
# Out:
# (23040, 3)

# %% [markdown]
# Here, k-means will be employed to distinguish the cancer cells from the background.
#
# Start by clustering the pixels (i.e., the rows of X) using the k-means algorithm with k=2. Then, assign the color white (1,1,1) to each pixel in cluster 0, and the color black (0,0,0) to each pixel in cluster 1. Finally, visualize the resulting image.

# %% [markdown]
# ## Part 3: detecting tumors

# %% [markdown]
# In this section, you will apply the k-means clustering algorithm to segment an MRI image and attempt to detect tumors.

# %%
# load the image
url = 'https://raw.githubusercontent.com/um-perez-alvaro/Data-Science-Theory/master/Data/tumor.csv'
image = pd.read_csv(url,header=None).to_numpy()
image.shape
# Out:
# (571, 512)

# %% [markdown]
# The file tumor.csv contains an MRI brain image of a patient with oligodendroglioma, which is a tumor that frequently arises in the frontal lobe of the brain.

# %%
plt.imshow(image,cmap='gray')
plt.axis(False)
plt.show()

# %%
X = image.reshape(-1,1)
X.shape
# Out:
# (292352, 1)

# %% [markdown]
# Cluster the pixels, and ensure that you have an appropriate number of clusters by applying the 'elbow' method, for example

# %% [markdown]
# Verify that one of the clusters corresponds, to some extent, with the tumor
