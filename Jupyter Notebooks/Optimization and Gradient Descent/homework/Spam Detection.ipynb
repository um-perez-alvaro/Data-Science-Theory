# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# # Problem 3: Email Spam Detection

# %% [markdown]
# The "spambase" dataset is a collection of 4,601 e-mails, out of which 1,813 are classified as spam, making up 39.4% of the dataset.
# The e-mails have undergone processing, which resulted in 57 real-valued features extracted and used for classification purposes, where most of the features indicate the frequency of occurrence of specific words or characters in the email.
# Additionally, each e-mail is labeled as either spam or non-spam.

# %%
# load the data
url = 'https://raw.githubusercontent.com/um-perez-alvaro/Data-Science-Theory/master/Data/spambase.csv'
data = pd.read_csv(url)
data
# Out:
#       attribute 0  attribute 1  attribute 2  attribute 3  attribute 4  \
# 0            0.00         0.64         0.64          0.0         0.32
# 1            0.21         0.28         0.50          0.0         0.14
# 2            0.06         0.00         0.71          0.0         1.23
# 3            0.00         0.00         0.00          0.0         0.63
# 4            0.00         0.00         0.00          0.0         0.63
# ...           ...          ...          ...          ...          ...
# 4596         0.31         0.00         0.62          0.0         0.00
# 4597         0.00         0.00         0.00          0.0         0.00
# 4598         0.30         0.00         0.30          0.0         0.00
# 4599         0.96         0.00         0.00          0.0         0.32
# 4600         0.00         0.00         0.65          0.0         0.00
#
#       attribute 5  attribute 6  attribute 7  attribute 8  attribute 9  ...  \
# ...

# %% [markdown]
# **Attribute Information:**
#
# The final column of the dataset shows whether the email is classified as spam or not, with the value 1 indicating spam and 0 indicating non-spam.
# Most of the features indicate the frequency of occurrence of specific words or characters in the email.
# Additionally, there are three run-length attributes (55-57) that measure the length of sequences of consecutive capital letters.
#
#
# | Attribute | Description |
# | :- | -: |
# | Attributes 0--47 | 48 continuous attributes of type word_freq_WORD = percentage of words in the e-mail that match WORD, i.e. 100 * (number of times the WORD appears in the e-mail) / total number of words in e-mail |
# | Attributes 48--53 | 6 continuous attributes of type char_freq_CHAR= percentage of characters in the e-mail that match CHAR, i.e. 100 * (number of CHAR occurences) / total characters in e-mail |
# | Attribute 54 | 1 continuous  attribute of type capital_run_length_average = average length of uninterrupted sequences of capital letters |
# | Attribute 55 | 1 integer attribute of type capital_run_length_longest = length of longest uninterrupted sequence of capital letters |
# | Attribute 56 | 1 integer attribute of type capital_run_length_total = sum of length of uninterrupted sequences of capital letters = total number of capital letters in the e-mail |
# | label |  whether the e-mail was considered spam (1) or not (0) |
#
# For more detailed information about these features, see the documentation provided [here](http://archive.ics.uci.edu/ml/datasets/Spambase).

# %% [markdown]
# In this problem, the goal is to fit  a linear regression model that can detect e-mail spam using the features in the "spambase" dataset.
# The model will predict whether an e-mail is spam or not.

# %%
X = data.iloc[:,0:57].to_numpy() # attributes
y = data['label'].to_numpy() # labels

# %% [markdown]
# ## Part 1

# %% [markdown]
# To ensure that the training and test sets are representative of the entire dataset, you will shuffle the data using a random permutation, which can be generated using ``np.random.permutation``.
# After shuffling, you will partition the data into a training set and a test set, denoted by X_train, y_train and X_test, y_test, respectively.

# %% [markdown]
# First, randomly shuffle the spambase dataset using `np.random.permutation`.

# %%
# shuffle the data

# %% [markdown]
# Then, partition the data into training and test sets X_train, y_train and X_test, y_test, respectively.

# %%
# split the data

# %% [markdown]
# ## Part 2

# %% [markdown]
# Use the training data X_train, y_train to fit a linear regression model that predicts the target variable y_train.

# %%
# fit the model

# %% [markdown]
# ## Part 3

# %% [markdown]
# Use your fitted linear regression model to predict the spam labels of the test set, and then compare the predicted labels with the true labels to calculate the accuracy (the percentage of correctly classified) of the model.

# %%
# accuracy on the test set
