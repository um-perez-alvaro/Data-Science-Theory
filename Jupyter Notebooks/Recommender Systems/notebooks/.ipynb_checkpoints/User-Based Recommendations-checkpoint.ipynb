# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# # User-based recommendations

# %%
# the file is in a Box folder 
ratings = pd.read_csv('ratings_large.csv')
ratings
# Out:
#           userId  movieId  rating   timestamp  \
# 0              4        1     4.0  1113765937
# 1              4        2     4.0  1113767306
# 2              4        5     2.0  1123990453
# 3              4        6     4.5  1113767242
# 4              4       10     4.0  1113765995
# ...          ...      ...     ...         ...
# 10395149  283224     1388     2.0   851001995
# 10395150  283224     1394     3.0   851002354
# 10395151  283224     1396     3.0   851002354
# 10395152  283224     2019     5.0   851000812
# 10395153  283224     5060     5.0   851000907
#
#                                                 title
# 0                                    Toy Story (1995)
# 1                                      Jumanji (1995)
# 2                  Father of the Bride Part II (1995)
# 3                                         Heat (1995)
# 4                                    GoldenEye (1995)
# ...                                               ...
# 10395149                                Jaws 2 (1978)
# 10395150                       Raising Arizona (1987)
# 10395151                              Sneakers (1992)
# 10395152  Seven Samurai (Shichinin no samurai) (1954)
# 10395153                 M*A*S*H (a.k.a. MASH) (1970)
#
# [10395154 rows x 5 columns]

# %%
# (transpose) ratings matrix
ratings_matrix = ratings.pivot(index='title',columns='userId',values='rating')
ratings_matrix
# Out:
# userId                                              4       19      42      \
# title
# (500) Days of Summer (2009)                            NaN     NaN     4.0
# 10 Things I Hate About You (1999)                      NaN     NaN     NaN
# 101 Dalmatians (1996)                                  NaN     NaN     4.0
# 101 Dalmatians (One Hundred and One Dalmatians)...     NaN     NaN     NaN
# 12 Angry Men (1957)                                    1.5     5.0     NaN
# ...                                                    ...     ...     ...
# Zoolander (2001)                                       NaN     NaN     NaN
# Zootopia (2016)                                        NaN     NaN     NaN
# eXistenZ (1999)                                        3.5     NaN     NaN
# xXx (2002)                                             3.5     NaN     NaN
# ¡Three Amigos! (1986)                                  3.0     NaN     NaN
#
# userId                                              43      51      55      \
# title
# (500) Days of Summer (2009)                            NaN     NaN     NaN
# 10 Things I Hate About You (1999)                      NaN     NaN     1.5
# 101 Dalmatians (1996)                                  NaN     NaN     NaN
# 101 Dalmatians (One Hundred and One Dalmatians)...     NaN     NaN     3.5
# 12 Angry Men (1957)                                    4.5     5.0     NaN
# ...                                                    ...     ...     ...
# Zoolander (2001)                                       NaN     NaN     NaN
# Zootopia (2016)                                        NaN     NaN     NaN
# eXistenZ (1999)                                        NaN     NaN     NaN
# xXx (2002)                                             NaN     NaN     NaN
# ¡Three Amigos! (1986)                                  3.0     3.0     NaN
#
# userId                                              56      71      73      \
# title
# (500) Days of Summer (2009)                            NaN     2.5     4.5
# 10 Things I Hate About You (1999)                      NaN     NaN     NaN
# 101 Dalmatians (1996)                                  0.5     NaN     NaN
# 101 Dalmatians (One Hundred and One Dalmatians)...     1.0     NaN     NaN
# 12 Angry Men (1957)                                    4.0     NaN     NaN
# ...                                                    ...     ...     ...
# Zoolander (2001)                                       2.5     NaN     2.5
# Zootopia (2016)                                        NaN     NaN     NaN
# eXistenZ (1999)                                        NaN     NaN     NaN
# xXx (2002)                                             NaN     NaN     NaN
# ¡Three Amigos! (1986)                                  NaN     NaN     NaN
#
# userId                                              79      ...  283153  \
# title                                                       ...
# (500) Days of Summer (2009)                            NaN  ...     NaN
# 10 Things I Hate About You (1999)                      4.0  ...     3.0
# 101 Dalmatians (1996)                                  NaN  ...     NaN
# 101 Dalmatians (One Hundred and One Dalmatians)...     NaN  ...     NaN
# 12 Angry Men (1957)                                    NaN  ...     NaN
# ...                                                    ...  ...     ...
# Zoolander (2001)                                       NaN  ...     3.0
# Zootopia (2016)                                        NaN  ...     NaN
# eXistenZ (1999)                                        NaN  ...     NaN
# xXx (2002)                                             NaN  ...     0.5
# ¡Three Amigos! (1986)                                  NaN  ...     NaN
#
# userId                                              283164  283165  283170  \
# title
# (500) Days of Summer (2009)                            NaN     NaN     4.0
# 10 Things I Hate About You (1999)                      NaN     4.5     NaN
# 101 Dalmatians (1996)                                  NaN     NaN     NaN
# 101 Dalmatians (One Hundred and One Dalmatians)...     NaN     NaN     NaN
# 12 Angry Men (1957)                                    NaN     3.0     NaN
# ...                                                    ...     ...     ...
# Zoolander (2001)                                       NaN     NaN     NaN
# Zootopia (2016)                                        NaN     NaN     NaN
# eXistenZ (1999)                                        NaN     NaN     NaN
# xXx (2002)                                             NaN     NaN     NaN
# ¡Three Amigos! (1986)                                  NaN     NaN     NaN
#
# userId                                              283183  283184  283185  \
# title
# (500) Days of Summer (2009)                            NaN     4.0     NaN
# 10 Things I Hate About You (1999)                      NaN     NaN     NaN
# 101 Dalmatians (1996)                                  NaN     NaN     NaN
# 101 Dalmatians (One Hundred and One Dalmatians)...     NaN     NaN     3.0
# 12 Angry Men (1957)                                    NaN     NaN     NaN
# ...                                                    ...     ...     ...
# Zoolander (2001)                                       NaN     2.0     NaN
# Zootopia (2016)                                        NaN     NaN     NaN
# eXistenZ (1999)                                        NaN     NaN     NaN
# xXx (2002)                                             NaN     NaN     NaN
# ¡Three Amigos! (1986)                                  NaN     NaN     NaN
#
# userId                                              283195  283204  283224
# title
# (500) Days of Summer (2009)                            NaN     NaN     NaN
# 10 Things I Hate About You (1999)                      2.5     NaN     NaN
# 101 Dalmatians (1996)                                  NaN     NaN     NaN
# 101 Dalmatians (One Hundred and One Dalmatians)...     4.5     NaN     NaN
# 12 Angry Men (1957)                                    NaN     NaN     5.0
# ...                                                    ...     ...     ...
# Zoolander (2001)                                       3.5     NaN     NaN
# Zootopia (2016)                                        NaN     NaN     NaN
# eXistenZ (1999)                                        NaN     NaN     NaN
# xXx (2002)                                             NaN     NaN     NaN
# ¡Three Amigos! (1986)                                  4.5     NaN     NaN
#
# [1344 rows x 35289 columns]

# %%
# select a userId (this will be our "test" user)
user = 4
user_ratings = ratings_matrix.loc[:,user]
user_ratings
# Out:
# title
# (500) Days of Summer (2009)                               NaN
# 10 Things I Hate About You (1999)                         NaN
# 101 Dalmatians (1996)                                     NaN
# 101 Dalmatians (One Hundred and One Dalmatians) (1961)    NaN
# 12 Angry Men (1957)                                       1.5
#                                                          ...
# Zoolander (2001)                                          NaN
# Zootopia (2016)                                           NaN
# eXistenZ (1999)                                           3.5
# xXx (2002)                                                3.5
# ¡Three Amigos! (1986)                                     3.0
# Name: 4, Length: 1344, dtype: float64

# %%
# drop user column from the ratings matrix
ratings_matrix.drop(user,axis=1,inplace=True)

# %%
# alternatively: use a fake user

# fake user likes sci-fi films, action-adventures films, and doesn't like romance films, kid movies
url = 'https://raw.githubusercontent.com/um-perez-alvaro/Data-Science-Theory/master/Data/fake_user.csv'
user_ratings = pd.read_csv(url,index_col='title').squeeze("columns")
user_ratings
# Out:
# title
# (500) Days of Summer (2009)                              NaN
# 10 Things I Hate About You (1999)                        NaN
# 101 Dalmatians (1996)                                    NaN
# 101 Dalmatians (One Hundred and One Dalmatians) (1961)   NaN
# 12 Angry Men (1957)                                      NaN
#                                                           ..
# Zoolander (2001)                                         NaN
# Zootopia (2016)                                          NaN
# eXistenZ (1999)                                          NaN
# xXx (2002)                                               NaN
# ¡Three Amigos! (1986)                                    NaN
# Name: rating, Length: 1344, dtype: float64

# %%
# movies rated by the user
user_ratings[user_ratings.notna()].index.to_list()
# Out:
# ['2001: A Space Odyssey (1968)',
#  '2012 (2009)',
#  '28 Days Later (2002)',
#  '300 (2007)',
#  '3:10 to Yuma (2007)',
#  '50 First Dates (2004)',
#  'A.I. Artificial Intelligence (2001)',
#  'AVP: Alien vs. Predator (2004)',
#  'Abyss, The (1989)',
#  'Air Force One (1997)',
#  'Akira (1988)',
#  'Aladdin (1992)',
#  'Alice in Wonderland (2010)',
#  'Alien (1979)',
#  'Alien: Resurrection (1997)',
#  'Aliens (1986)',
#  'All About Eve (1950)',
#  'Amadeus (1984)',
#  "Amelie (Fabuleux destin d'Amélie Poulain, Le) (2001)",
#  'American Beauty (1999)',
#  'American Pie (1999)',
#  'American Pie 2 (2001)',
#  'American Psycho (2000)',
#  'Annie Hall (1977)',
#  'Apartment, The (1960)',
#  'Apocalypse Now (1979)',
#  'Apollo 13 (1995)',
#  'Aristocats, The (1970)',
#  'Arrival (2016)',
#  'Bambi (1942)',
#  'Basic Instinct (1992)',
#  'Batman Begins (2005)',
#  'Beautiful Mind, A (2001)',
#  'Before Sunrise (1995)',
#  'Before Sunset (2004)',
#  'Being John Malkovich (1999)',
#  'Ben-Hur (1959)',
#  'Big Fish (2003)',
#  'Big Lebowski, The (1998)',
#  'Black Hawk Down (2001)',
#  'Blade (1998)',
#  'Blade II (2002)',
#  'Blade Runner (1982)',
#  'Bourne Identity, The (2002)',
#  'Brave (2012)',
#  'Braveheart (1995)',
#  "Bridget Jones's Diary (2001)",
#  'Buffy the Vampire Slayer (1992)',
#  'Cape Fear (1991)',
#  'Captain America: Civil War (2016)',
#  'Captain America: The First Avenger (2011)',
#  'Captain America: The Winter Soldier (2014)',
#  'Casino (1995)',
#  "Charlie's Angels (2000)",
#  'Chocolat (2000)',
#  'Clockwork Orange, A (1971)',
#  'Cloud Atlas (2012)',
#  'Cloverfield (2008)',
#  'Contact (1997)',
#  'Coraline (2009)',
#  'Corpse Bride (2005)',
#  'Crazy, Stupid, Love. (2011)',
#  'Curious Case of Benjamin Button, The (2008)',
#  'Dances with Wolves (1990)',
#  'Dark City (1998)',
#  'Dark Knight, The (2008)',
#  'Dawn of the Dead (2004)',
#  'Day After Tomorrow, The (2004)',
#  'Day the Earth Stood Still, The (1951)',
#  'Dead Poets Society (1989)',
#  'Die Hard (1988)',
#  'Die Hard 2 (1990)',
#  'Die Hard: With a Vengeance (1995)',
#  'District 9 (2009)',
#  'Django Unchained (2012)',
#  'Doctor Strange (2016)',
#  'Doctor Zhivago (1965)',
#  'Dr. Dolittle (1998)',
#  'Dragonheart (1996)',
#  'Driving Miss Daisy (1989)',
#  'Duck Soup (1933)',
#  "Dude, Where's My Car? (2000)",
#  'Enemy at the Gates (2001)',
#  'Equilibrium (2002)',
#  'Escape from L.A. (1996)',
#  'Escape from New York (1981)',
#  'Eternal Sunshine of the Spotless Mind (2004)',
#  'Event Horizon (1997)',
#  'Evil Dead, The (1981)',
#  'Evolution (2001)',
#  'Ex Machina (2015)',
#  'Eyes Wide Shut (1999)',
#  'Fantastic Four (2005)',
#  'Fantastic Mr. Fox (2009)',
#  'Fargo (1996)',
#  'Fifth Element, The (1997)',
#  'Fight Club (1999)',
#  'Finding Nemo (2003)',
#  'Forgetting Sarah Marshall (2008)',
#  'Forrest Gump (1994)',
#  'Fox and the Hound, The (1981)',
#  'Frozen (2013)',
#  'Gangs of New York (2002)',
#  'Gattaca (1997)',
#  'Ghostbusters (a.k.a. Ghost Busters) (1984)',
#  'Ghostbusters II (1989)',
#  'Girl with the Dragon Tattoo, The (2011)',
#  'Girl with the Dragon Tattoo, The (Män som hatar kvinnor) (2009)',
#  'Gladiator (2000)',
#  'Godfather, The (1972)',
#  'Godfather: Part II, The (1974)',
#  'Godzilla (1998)',
#  'Goodfellas (1990)',
#  'Goonies, The (1985)',
#  'Gran Torino (2008)',
#  'Gravity (2013)',
#  'Grease (1978)',
#  'Gremlins (1984)',
#  'Groundhog Day (1993)',
#  'Harry Potter and the Chamber of Secrets (2002)',
#  'Harry Potter and the Deathly Hallows: Part 1 (2010)',
#  'Harry Potter and the Deathly Hallows: Part 2 (2011)',
#  'Harry Potter and the Goblet of Fire (2005)',
#  'Harry Potter and the Half-Blood Prince (2009)',
#  'Harry Potter and the Order of the Phoenix (2007)',
#  'Harry Potter and the Prisoner of Azkaban (2004)',
#  "Harry Potter and the Sorcerer's Stone (a.k.a. Harry Potter and the Philosopher's Stone) (2001)",
#  'Her (2013)',
#  'Hero (Ying xiong) (2002)',
#  'Hobbit: An Unexpected Journey, The (2012)',
#  'Hobbit: The Desolation of Smaug, The (2013)',
#  'Hook (1991)',
#  'How to Train Your Dragon (2010)',
#  "Howl's Moving Castle (Hauru no ugoku shiro) (2004)",
#  'Hunt for Red October, The (1990)',
#  'I, Robot (2004)',
#  'Ice Age (2002)',
#  'Ice Age 2: The Meltdown (2006)',
#  'Incredibles, The (2004)',
#  'Independence Day (a.k.a. ID4) (1996)',
#  'Indiana Jones and the Kingdom of the Crystal Skull (2008)',
#  'Indiana Jones and the Last Crusade (1989)',
#  'Indiana Jones and the Temple of Doom (1984)',
#  'Inglourious Basterds (2009)',
#  'Inside Out (2015)',
#  'Interstellar (2014)',
#  'Interview with the Vampire: The Vampire Chronicles (1994)',
#  'Invasion of the Body Snatchers (1956)',
#  'Iron Giant, The (1999)',
#  'Iron Man (2008)',
#  'Iron Man 2 (2010)',
#  'Island of Dr. Moreau, The (1996)',
#  'Island, The (2005)',
#  "It's a Wonderful Life (1946)",
#  'Jaws (1975)',
#  'Jurassic Park (1993)',
#  'Jurassic Park III (2001)',
#  'K-PAX (2001)',
#  'Kick-Ass (2010)',
#  'Kill Bill: Vol. 1 (2003)',
#  "King's Speech, The (2010)",
#  'Kung Fu Panda (2008)',
#  'Labyrinth (1986)',
#  'Lawrence of Arabia (1962)',
#  'Life Is Beautiful (La Vita è bella) (1997)',
#  'Life of Pi (2012)',
#  'Lilo & Stitch (2002)',
#  'Lion King, The (1994)',
#  'Little Mermaid, The (1989)',
#  'Little Miss Sunshine (2006)',
#  'Little Princess, A (1995)',
#  'Little Women (1994)',
#  'Lord of the Rings: The Fellowship of the Ring, The (2001)',
#  'Lord of the Rings: The Two Towers, The (2002)',
#  'Lost World: Jurassic Park, The (1997)',
#  'Lost in Translation (2003)',
#  'Love Actually (2003)',
#  'Madagascar (2005)',
#  'Magnolia (1999)',
#  'Man in the Iron Mask, The (1998)',
#  'Mary Poppins (1964)',
#  'Mask of Zorro, The (1998)',
#  'Master and Commander: The Far Side of the World (2003)',
#  'Matilda (1996)',
#  'Matrix, The (1999)',
#  'Meet Joe Black (1998)',
#  'Meet the Fockers (2004)',
#  'Meet the Parents (2000)',
#  'Men in Black (a.k.a. MIB) (1997)',
#  'Million Dollar Baby (2004)',
#  'Mission: Impossible (1996)',
#  "Monty Python's Life of Brian (1979)",
#  'Moulin Rouge (2001)',
#  'Mrs. Doubtfire (1993)',
#  'Mulan (1998)',
#  'Mulholland Drive (2001)',
#  'Muppet Movie, The (1979)',
#  'Muppet Treasure Island (1996)',
#  'Mystic River (2003)',
#  'Nausicaä of the Valley of the Wind (Kaze no tani no Naushika) (1984)',
#  'NeverEnding Story, The (1984)',
#  'Night of the Living Dead (1968)',
#  'No Country for Old Men (2007)',
#  'Notebook, The (2004)',
#  "Ocean's Eleven (2001)",
#  "Pan's Labyrinth (Laberinto del fauno, El) (2006)",
#  'Pay It Forward (2000)',
#  'Pearl Harbor (2001)',
#  'Peter Pan (1953)',
#  'Pianist, The (2002)',
#  'Pinocchio (1940)',
#  'Planet of the Apes (1968)',
#  'Planet of the Apes (2001)',
#  'Pocahontas (1995)',
#  'Pretty Woman (1990)',
#  'Princess Bride, The (1987)',
#  'Princess Diaries, The (2001)',
#  'Princess Mononoke (Mononoke-hime) (1997)',
#  'Pulp Fiction (1994)',
#  'Quantum of Solace (2008)',
#  'Ratatouille (2007)',
#  'Remains of the Day, The (1993)',
#  'Requiem for a Dream (2000)',
#  'Reservoir Dogs (1992)',
#  'Resident Evil (2002)',
#  'Rise of the Planet of the Apes (2011)',
#  'Rogue One: A Star Wars Story (2016)',
#  'Runaway Bride (1999)',
#  'Saving Private Ryan (1998)',
#  'Scarface (1983)',
#  "Schindler's List (1993)",
#  'Seven (a.k.a. Se7en) (1995)',
#  'Shadowlands (1993)',
#  'Shaun of the Dead (2004)',
#  'Shawshank Redemption, The (1994)',
#  'Sherlock Holmes (2009)',
#  'Shining, The (1980)',
#  'Showgirls (1995)',
#  'Shrek (2001)',
#  'Shrek 2 (2004)',
#  'Shutter Island (2010)',
#  'Slumdog Millionaire (2008)',
#  'Sound of Music, The (1965)',
#  'Space Jam (1996)',
#  'Spirited Away (Sen to Chihiro no kamikakushi) (2001)',
#  'Star Trek (2009)',
#  'Star Trek II: The Wrath of Khan (1982)',
#  'Starship Troopers (1997)',
#  'Tarzan (1999)',
#  'Teenage Mutant Ninja Turtles (1990)',
#  'Terminator 2: Judgment Day (1991)',
#  'Terminator 3: Rise of the Machines (2003)',
#  'Terminator, The (1984)',
#  'The Hateful Eight (2015)',
#  'The Hunger Games (2012)',
#  'The Hunger Games: Catching Fire (2013)',
#  'The Hunger Games: Mockingjay - Part 1 (2014)',
#  'The Imitation Game (2014)',
#  'The Lego Movie (2014)',
#  'The Martian (2015)',
#  'Titan A.E. (2000)',
#  'Titanic (1997)',
#  'To Kill a Mockingbird (1962)',
#  'Toy Story (1995)',
#  'Toy Story 2 (1999)',
#  'Toy Story 3 (2010)',
#  'Trainspotting (1996)',
#  'Troy (2004)',
#  'True Romance (1993)',
#  'Twelve Monkeys (a.k.a. 12 Monkeys) (1995)',
#  'Twilight (2008)',
#  'Up (2009)',
#  'Up in the Air (2009)',
#  'V for Vendetta (2006)',
#  'Village, The (2004)',
#  'WALL·E (2008)',
#  'War of the Worlds (2005)',
#  'What Dreams May Come (1998)',
#  'When Harry Met Sally... (1989)',
#  'Whiplash (2014)',
#  'Who Framed Roger Rabbit? (1988)',
#  "William Shakespeare's Romeo + Juliet (1996)",
#  'Wolf of Wall Street, The (2013)',
#  'World War Z (2013)',
#  'X-Men (2000)']

# %%
# movies not rated by the user
user_ratings[user_ratings.isna()].index.to_list()
# Out:
# ['(500) Days of Summer (2009)',
#  '10 Things I Hate About You (1999)',
#  '101 Dalmatians (1996)',
#  '101 Dalmatians (One Hundred and One Dalmatians) (1961)',
#  '12 Years a Slave (2013)',
#  '127 Hours (2010)',
#  '13th Warrior, The (1999)',
#  '20,000 Leagues Under the Sea (1954)',
#  '2012 (2009)',
#  '21 Grams (2003)',
#  '21 Jump Street (2012)',
#  '28 Days (2000)',
#  '28 Days Later (2002)',
#  '3:10 to Yuma (2007)',
#  '40-Year-Old Virgin, The (2005)',
#  '50 First Dates (2004)',
#  '6th Day, The (2000)',
#  '8 Mile (2002)',
#  'A.I. Artificial Intelligence (2001)',
#  'About a Boy (2002)',
#  'Adaptation (2002)',
#  'Addams Family, The (1991)',
#  'Adventures of Priscilla, Queen of the Desert, The (1994)',
#  'African Queen, The (1951)',
#  'Airheads (1994)',
#  'Alice in Wonderland (1951)',
#  'Alice in Wonderland (2010)',
#  'All About Eve (1950)',
#  'All About My Mother (Todo sobre mi madre) (1999)',
#  "All the President's Men (1976)",
#  'Almost Famous (2000)',
#  'Amadeus (1984)',
#  'Amazing Spider-Man, The (2012)',
#  "Amelie (Fabuleux destin d'Amélie Poulain, Le) (2001)",
#  'American Graffiti (1973)',
#  'American History X (1998)',
#  'American Psycho (2000)',
#  'American Tail, An (1986)',
#  'American Werewolf in London, An (1981)',
#  'Amistad (1997)',
#  "Amores Perros (Love's a Bitch) (2000)",
#  'Anaconda (1997)',
#  'Anastasia (1997)',
#  'And Your Mother Too (Y tu mamá también) (2001)',
#  'Anger Management (2003)',
#  'Animal House (1978)',
#  'Annie Hall (1977)',
#  'Ant-Man (2015)',
#  'Apartment, The (1960)',
#  'Arachnophobia (1990)',
#  'Argo (2012)',
#  'Aristocats, The (1970)',
#  'Arlington Road (1999)',
#  'Arrival (2016)',
#  'Arrival, The (1996)',
#  'Arsenic and Old Lace (1944)',
#  'Avatar (2009)',
#  'Avengers, The (2012)',
#  'Avengers: Age of Ultron (2015)',
#  'Aviator, The (2004)',
#  'Awakenings (1990)',
#  'Babe: Pig in the City (1998)',
#  'Babel (2006)',
#  'Bad Santa (2003)',
#  'Bambi (1942)',
#  'Barb Wire (1996)',
#  'Basketball Diaries, The (1995)',
#  'Battle Royale (Batoru rowaiaru) (2000)',
#  'Beach, The (2000)',
#  'Bedazzled (2000)',
#  'Bedknobs and Broomsticks (1971)',
#  'Before Sunrise (1995)',
#  'Before Sunset (2004)',
#  'Being There (1979)',
#  'Ben-Hur (1959)',
#  'Bend It Like Beckham (2002)',
#  'Benny & Joon (1993)',
#  'Best in Show (2000)',
#  'Better Off Dead... (1985)',
#  'Beverly Hillbillies, The (1993)',
#  'Big Chill, The (1983)',
#  'Big Daddy (1999)',
#  'Big Hero 6 (2014)',
#  'Big Night (1996)',
#  'Big Short, The (2015)',
#  'Big Sleep, The (1946)',
#  'Billy Elliot (2000)',
#  'Birdman: Or (The Unexpected Virtue of Ignorance) (2014)',
#  'Birds, The (1963)',
#  'Black Sheep (1996)',
#  'Black Swan (2010)',
#  'Blazing Saddles (1974)',
#  'Blind Side, The  (2009)',
#  'Blood Diamond (2006)',
#  'Blood Simple (1984)',
#  'Blue Velvet (1986)',
#  'Bodyguard, The (1992)',
#  'Bone Collector, The (1999)',
#  'Bonnie and Clyde (1967)',
#  'Book of Eli, The (2010)',
#  'Boot, Das (Boat, The) (1981)',
#  'Borat: Cultural Learnings of America for Make Benefit Glorious Nation of Kazakhstan (2006)',
#  'Bound (1996)',
#  'Bowling for Columbine (2002)',
#  "Boys Don't Cry (1999)",
#  'Brady Bunch Movie, The (1995)',
#  'Brave (2012)',
#  'Brazil (1985)',
#  "Breakfast at Tiffany's (1961)",
#  'Bridge on the River Kwai, The (1957)',
#  'Bridges of Madison County, The (1995)',
#  'Bring It On (2000)',
#  'Bringing Up Baby (1938)',
#  'Broadcast News (1987)',
#  'Brokeback Mountain (2005)',
#  'Bronx Tale, A (1993)',
#  'Bull Durham (1988)',
#  'Bullets Over Broadway (1994)',
#  'Bulworth (1998)',
#  'Burn After Reading (2008)',
#  'Butch Cassidy and the Sundance Kid (1969)',
#  'Cabin in the Woods, The (2012)',
#  'Cape Fear (1991)',
#  'Captain America: Civil War (2016)',
#  'Captain America: The First Avenger (2011)',
#  'Captain America: The Winter Soldier (2014)',
#  "Carlito's Way (1993)",
#  'Carrie (1976)',
#  'Cars (2006)',
#  'Casablanca (1942)',
#  'Casino Royale (2006)',
#  'Cell, The (2000)',
#  'Chariots of Fire (1981)',
#  'Charlie and the Chocolate Factory (2005)',
#  "Charlie's Angels: Full Throttle (2003)",
#  "Charlotte's Web (1973)",
#  'Chasing Amy (1997)',
#  'Chicago (2002)',
#  'Chinatown (1974)',
#  'Chocolat (2000)',
#  'Christmas Story, A (1983)',
#  "Christmas Vacation (National Lampoon's Christmas Vacation) (1989)",
#  'Chronicles of Narnia: The Lion, the Witch and the Wardrobe, The (2005)',
#  'Cider House Rules, The (1999)',
#  'Cinderella (1950)',
#  'Cinderella Man (2005)',
#  'Cinema Paradiso (Nuovo cinema Paradiso) (1989)',
#  'Circle of Friends (1995)',
#  'Citizen Kane (1941)',
#  'City of Angels (1998)',
#  'City of Lost Children, The (Cité des enfants perdus, La) (1995)',
#  'Click (2006)',
#  'Clockwork Orange, A (1971)',
#  'Close Encounters of the Third Kind (1977)',
#  'Closer (2004)',
#  'Cloud Atlas (2012)',
#  'Cloverfield (2008)',
#  'Clue (1985)',
#  'Color Purple, The (1985)',
#  'Coming to America (1988)',
#  'Commitments, The (1991)',
#  'Conan the Barbarian (1982)',
#  'Cool Hand Luke (1967)',
#  'Cop Land (1997)',
#  'Copycat (1995)',
#  'Coraline (2009)',
#  'Corpse Bride (2005)',
#  'Crash (2004)',
#  'Crazy, Stupid, Love. (2011)',
#  'Crumb (1994)',
#  'Cube (1997)',
#  'Curious Case of Benjamin Button, The (2008)',
#  'Da Vinci Code, The (2006)',
#  'Dallas Buyers Club (2013)',
#  'Dangerous Liaisons (1988)',
#  "Dante's Peak (1997)",
#  'Daredevil (2003)',
#  'Darjeeling Limited, The (2007)',
#  'Dark Knight Rises, The (2012)',
#  'Dark Knight, The (2008)',
#  'Dawn of the Dead (2004)',
#  'Day the Earth Stood Still, The (1951)',
#  'Dazed and Confused (1993)',
#  'Dead Poets Society (1989)',
#  'Deadpool (2016)',
#  'Deer Hunter, The (1978)',
#  'Delicatessen (1991)',
#  'Deliverance (1972)',
#  'Departed, The (2006)',
#  'Desperately Seeking Susan (1985)',
#  'Despicable Me (2010)',
#  'Devil Wears Prada, The (2006)',
#  'Dial M for Murder (1954)',
#  'Dirty Dozen, The (1967)',
#  'Dirty Harry (1971)',
#  'Disclosure (1994)',
#  'District 9 (2009)',
#  'Django Unchained (2012)',
#  'Do the Right Thing (1989)',
#  'Doctor Strange (2016)',
#  'Doctor Zhivago (1965)',
#  'Dog Day Afternoon (1975)',
#  'Dolores Claiborne (1995)',
#  'Don Juan DeMarco (1995)',
#  'Doors, The (1991)',
#  'Double Indemnity (1944)',
#  'Down Periscope (1996)',
#  'Downfall (Untergang, Der) (2004)',
#  'Dr. Dolittle (1998)',
#  'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1964)',
#  'Drive (2011)',
#  'Driving Miss Daisy (1989)',
#  'Duck Soup (1933)',
#  'Dumbo (1941)',
#  'Déjà Vu (Deja Vu) (2006)',
#  'E.T. the Extra-Terrestrial (1982)',
#  'Easy A (2010)',
#  'Easy Rider (1969)',
#  'Eat Drink Man Woman (Yin shi nan nu) (1994)',
#  'Ed Wood (1994)',
#  'Edge of Tomorrow (2014)',
#  'Election (1999)',
#  'Elephant Man, The (1980)',
#  'Elf (2003)',
#  'Elizabeth (1998)',
#  'Emma (1996)',
#  "Emperor's New Groove, The (2000)",
#  'English Patient, The (1996)',
#  'Englishman Who Went Up a Hill But Came Down a Mountain, The (1995)',
#  'Erin Brockovich (2000)',
#  'Escape from L.A. (1996)',
#  'Escape from New York (1981)',
#  'Ever After: A Cinderella Story (1998)',
#  'Evil Dead II (Dead by Dawn) (1987)',
#  'Evil Dead, The (1981)',
#  'Evita (1996)',
#  'Ex Machina (2015)',
#  'Excalibur (1981)',
#  'Exorcist, The (1973)',
#  'Face/Off (1997)',
#  'Faculty, The (1998)',
#  'Family Man, The (2000)',
#  'Fantasia (1940)',
#  'Fantastic Four (2005)',
#  'Fantastic Mr. Fox (2009)',
#  'Fast Times at Ridgemont High (1982)',
#  'Fast and the Furious, The (2001)',
#  'Fatal Attraction (1987)',
#  'Femme Nikita, La (Nikita) (1990)',
#  'Field of Dreams (1989)',
#  'Final Destination (2000)',
#  'Finding Neverland (2004)',
#  'First Blood (Rambo: First Blood) (1982)',
#  'First Knight (1995)',
#  'First Wives Club, The (1996)',
#  'Fisher King, The (1991)',
#  'Fistful of Dollars, A (Per un pugno di dollari) (1964)',
#  'Fletch (1985)',
#  'Flintstones, The (1994)',
#  'Flubber (1997)',
#  'Fly, The (1986)',
#  'For a Few Dollars More (Per qualche dollaro in più) (1965)',
#  'Forget Paris (1995)',
#  'Forgetting Sarah Marshall (2008)',
#  'Four Rooms (1995)',
#  'Four Weddings and a Funeral (1994)',
#  'Fox and the Hound, The (1981)',
#  'French Connection, The (1971)',
#  'French Kiss (1995)',
#  'Frequency (2000)',
#  'Friday (1995)',
#  'Fried Green Tomatoes (1991)',
#  'Frighteners, The (1996)',
#  'From Hell (2001)',
#  'Frozen (2013)',
#  'Galaxy Quest (1999)',
#  'Gandhi (1982)',
#  'Garden State (2004)',
#  'George of the Jungle (1997)',
#  'Get Shorty (1995)',
#  'Ghost Dog: The Way of the Samurai (1999)',
#  'Ghost World (2001)',
#  'Girl with the Dragon Tattoo, The (2011)',
#  'Girl with the Dragon Tattoo, The (Män som hatar kvinnor) (2009)',
#  'Girl, Interrupted (1999)',
#  'Glengarry Glen Ross (1992)',
#  'Go (1999)',
#  'Godfather: Part II, The (1974)',
#  'Godfather: Part III, The (1990)',
#  'Gone Girl (2014)',
#  'Gone with the Wind (1939)',
#  'Good bye, Lenin! (2003)',
#  'Good, the Bad and the Ugly, The (Buono, il brutto, il cattivo, Il) (1966)',
#  'Goodfellas (1990)',
#  'Goonies, The (1985)',
#  'Gosford Park (2001)',
#  'Graduate, The (1967)',
#  'Gran Torino (2008)',
#  'Grand Budapest Hotel, The (2014)',
#  'Grand Day Out with Wallace and Gromit, A (1989)',
#  'Gravity (2013)',
#  'Grease (1978)',
#  'Great Escape, The (1963)',
#  'Green Mile, The (1999)',
#  'Grifters, The (1990)',
#  'Grindhouse (2007)',
#  'Grumpier Old Men (1995)',
#  'Grumpy Old Men (1993)',
#  'Guardians of the Galaxy (2014)',
#  'Halloween (1978)',
#  'Hamlet (1996)',
#  'Hancock (2008)',
#  'Hangover, The (2009)',
#  'Happiness (1998)',
#  'Harold and Maude (1971)',
#  'Harry Potter and the Deathly Hallows: Part 1 (2010)',
#  'Harry Potter and the Deathly Hallows: Part 2 (2011)',
#  'Harry Potter and the Goblet of Fire (2005)',
#  'Harry Potter and the Half-Blood Prince (2009)',
#  'Harry Potter and the Order of the Phoenix (2007)',
#  'Harry Potter and the Prisoner of Azkaban (2004)',
#  'Haunting, The (1999)',
#  'Heathers (1989)',
#  'Heavenly Creatures (1994)',
#  'Help, The (2011)',
#  'Her (2013)',
#  'Hercules (1997)',
#  'Hero (Ying xiong) (2002)',
#  'High Noon (1952)',
#  'History of the World: Part I (1981)',
#  'Hitch (2005)',
#  'Hobbit: An Unexpected Journey, The (2012)',
#  'Hobbit: The Desolation of Smaug, The (2013)',
#  'Hoop Dreams (1994)',
#  'Hoosiers (a.k.a. Best Shot) (1986)',
#  'Hot Fuzz (2007)',
#  'Hotel Rwanda (2004)',
#  'House of Flying Daggers (Shi mian mai fu) (2004)',
#  'How the Grinch Stole Christmas (a.k.a. The Grinch) (2000)',
#  'How to Lose a Guy in 10 Days (2003)',
#  'How to Train Your Dragon (2010)',
#  "Howl's Moving Castle (Hauru no ugoku shiro) (2004)",
#  'Hunchback of Notre Dame, The (1996)',
#  'Hurricane, The (1999)',
#  'Hurt Locker, The (2008)',
#  'I Am Legend (2007)',
#  'I Know What You Did Last Summer (1997)',
#  'I Still Know What You Did Last Summer (1998)',
#  'I.Q. (1994)',
#  'Ice Age 2: The Meltdown (2006)',
#  'Ice Storm, The (1997)',
#  'Identity (2003)',
#  'Illusionist, The (2006)',
#  'Immortal Beloved (1994)',
#  'In & Out (1997)',
#  'In Bruges (2008)',
#  'In Time (2011)',
#  'In the Name of the Father (1993)',
#  'Inception (2010)',
#  'Incredible Hulk, The (2008)',
#  'Indian in the Cupboard, The (1995)',
#  'Indiana Jones and the Kingdom of the Crystal Skull (2008)',
#  'Inglourious Basterds (2009)',
#  'Inside Out (2015)',
#  'Insider, The (1999)',
#  'Interstellar (2014)',
#  'Into the Wild (2007)',
#  'Intouchables (2011)',
#  'Invasion of the Body Snatchers (1956)',
#  'Iron Giant, The (1999)',
#  'Iron Man (2008)',
#  'Iron Man 2 (2010)',
#  'Iron Man 3 (2013)',
#  'Island of Dr. Moreau, The (1996)',
#  "It's a Wonderful Life (1946)",
#  'JFK (1991)',
#  'Jack (1996)',
#  'Jackie Brown (1997)',
#  "Jacob's Ladder (1990)",
#  'James and the Giant Peach (1996)',
#  'Jaws (1975)',
#  'Jaws 2 (1978)',
#  'Jerk, The (1979)',
#  'John Wick (2014)',
#  'Jungle Book, The (1967)',
#  'Jungle Book, The (1994)',
#  'Jurassic World (2015)',
#  'Juror, The (1996)',
#  'Karate Kid, Part II, The (1986)',
#  'Karate Kid, The (1984)',
#  'Kick-Ass (2010)',
#  'Killing Fields, The (1984)',
#  'King Kong (1933)',
#  'King Kong (2005)',
#  "King's Speech, The (2010)",
#  'Kingsman: The Secret Service (2015)',
#  'Kiss the Girls (1997)',
#  "Knight's Tale, A (2001)",
#  'Knocked Up (2007)',
#  'Kramer vs. Kramer (1979)',
#  'Kung Fu Panda (2008)',
#  'L.A. Story (1991)',
#  'Lady and the Tramp (1955)',
#  'Laputa: Castle in the Sky (Tenkû no shiro Rapyuta) (1986)',
#  'Last Emperor, The (1987)',
#  'Last King of Scotland, The (2006)',
#  'Last of the Mohicans, The (1992)',
#  'Lawrence of Arabia (1962)',
#  'Legally Blonde (2001)',
#  'Legends of the Fall (1994)',
#  "Lemony Snicket's A Series of Unfortunate Events (2004)",
#  'Let the Right One In (Låt den rätte komma in) (2008)',
#  'Life Aquatic with Steve Zissou, The (2004)',
#  'Life Is Beautiful (La Vita è bella) (1997)',
#  'Life of Pi (2012)',
#  'Like Water for Chocolate (Como agua para chocolate) (1992)',
#  'Lilo & Stitch (2002)',
#  'Limitless (2011)',
#  'Little Miss Sunshine (2006)',
#  'Little Princess, A (1995)',
#  'Little Shop of Horrors (1986)',
#  'Little Women (1994)',
#  'Lives of Others, The (Das leben der Anderen) (2006)',
#  'Logan (2017)',
#  "Logan's Run (1976)",
#  'Lone Star (1996)',
#  'Looper (2012)',
#  'Lord of the Rings, The (1978)',
#  'Lost Boys, The (1987)',
#  'Lost Highway (1997)',
#  'Lost in Translation (2003)',
#  'Love Actually (2003)',
#  'Lucky Number Slevin (2006)',
#  'M (1931)',
#  'M*A*S*H (a.k.a. MASH) (1970)',
#  'Mad Max: Fury Road (2015)',
#  'Madagascar (2005)',
#  'Madness of King George, The (1994)',
#  'Magnolia (1999)',
#  'Malcolm X (1992)',
#  'Maltese Falcon, The (1941)',
#  'Man Without a Face, The (1993)',
#  'Man in the Iron Mask, The (1998)',
#  'Man on Fire (2004)',
#  'Man on the Moon (1999)',
#  'Manchurian Candidate, The (1962)',
#  'Manhattan (1979)',
#  'Mariachi, El (1992)',
#  'Mary Poppins (1964)',
#  "Mary Shelley's Frankenstein (Frankenstein) (1994)",
#  'Match Point (2005)',
#  'Matilda (1996)',
#  'Me, Myself & Irene (2000)',
#  'Mean Girls (2004)',
#  'Meet Joe Black (1998)',
#  'Meet the Fockers (2004)',
#  'Megamind (2010)',
#  'Men in Black III (M.III.B.) (M.I.B.³) (2012)',
#  'Metropolis (1927)',
#  'Mexican, The (2001)',
#  'Michael (1996)',
#  'Midnight Cowboy (1969)',
#  'Midnight Run (1988)',
#  'Midnight in Paris (2011)',
#  'Midnight in the Garden of Good and Evil (1997)',
#  'Mighty Aphrodite (1995)',
#  'Milk Money (1994)',
#  "Miller's Crossing (1990)",
#  'Million Dollar Baby (2004)',
#  'Miracle on 34th Street (1947)',
#  'Miracle on 34th Street (1994)',
#  'Misery (1990)',
#  'Mission: Impossible - Ghost Protocol (2011)',
#  'Mission: Impossible III (2006)',
#  'Modern Times (1936)',
#  'Moneyball (2011)',
#  "Monster's Ball (2001)",
#  "Monty Python's And Now for Something Completely Different (1971)",
#  'Moon (2009)',
#  'Moonrise Kingdom (2012)',
#  'Moonstruck (1987)',
#  'Motorcycle Diaries, The (Diarios de motocicleta) (2004)',
#  'Mr. Smith Goes to Washington (1939)',
#  'Much Ado About Nothing (1993)',
#  'Mulan (1998)',
#  'Mulholland Drive (2001)',
#  'Multiplicity (1996)',
#  'Munich (2005)',
#  'Muppet Movie, The (1979)',
#  'Muppet Treasure Island (1996)',
#  'Murder in the First (1995)',
#  "Muriel's Wedding (1994)",
#  "My Best Friend's Wedding (1997)",
#  'My Fair Lady (1964)',
#  'My Left Foot (1989)',
#  'My Neighbor Totoro (Tonari no Totoro) (1988)',
#  'Mystery Science Theater 3000: The Movie (1996)',
#  'Mystic River (2003)',
#  'Name of the Rose, The (Name der Rose, Der) (1986)',
#  "National Lampoon's Vacation (1983)",
#  'Natural, The (1984)',
#  'Nausicaä of the Valley of the Wind (Kaze no tani no Naushika) (1984)',
#  'Nell (1994)',
#  'Network (1976)',
#  'Never Been Kissed (1999)',
#  'Night at the Museum (2006)',
#  'Night of the Living Dead (1968)',
#  'Nightcrawler (2014)',
#  'Nightmare Before Christmas, The (1993)',
#  'Nightmare on Elm Street, A (1984)',
#  'Nixon (1995)',
#  'No Country for Old Men (2007)',
#  'North by Northwest (1959)',
#  'Notebook, The (2004)',
#  'Notorious (1946)',
#  'Notting Hill (1999)',
#  'Now You See Me (2013)',
#  'Nurse Betty (2000)',
#  'O Brother, Where Art Thou? (2000)',
#  'Oblivion (2013)',
#  "Ocean's Thirteen (2007)",
#  "Ocean's Twelve (2004)",
#  'Omen, The (1976)',
#  'On Golden Pond (1981)',
#  'On the Waterfront (1954)',
#  'Once Upon a Time in America (1984)',
#  "Once Upon a Time in the West (C'era una volta il West) (1968)",
#  "One Flew Over the Cuckoo's Nest (1975)",
#  'One Hour Photo (2002)',
#  'Others, The (2001)',
#  'Out of Africa (1985)',
#  'Out of Sight (1998)',
#  "Pan's Labyrinth (Laberinto del fauno, El) (2006)",
#  'Panic Room (2002)',
#  'Papillon (1973)',
#  'Parent Trap, The (1961)',
#  'Parenthood (1989)',
#  'Patch Adams (1998)',
#  'Patton (1970)',
#  'Pay It Forward (2000)',
#  'Pearl Harbor (2001)',
#  'People vs. Larry Flynt, The (1996)',
#  'Perks of Being a Wallflower, The (2012)',
#  'Peter Pan (1953)',
#  'Phenomenon (1996)',
#  'Philadelphia (1993)',
#  'Philadelphia Story, The (1940)',
#  'Pianist, The (2002)',
#  'Piano, The (1993)',
#  'Pineapple Express (2008)',
#  'Pink Floyd: The Wall (1982)',
#  'Pinocchio (1940)',
#  "Pirates of the Caribbean: At World's End (2007)",
#  "Pirates of the Caribbean: Dead Man's Chest (2006)",
#  'Pirates of the Caribbean: On Stranger Tides (2011)',
#  'Planes, Trains & Automobiles (1987)',
#  'Planet of the Apes (1968)',
#  'Player, The (1992)',
#  'Pleasantville (1998)',
#  'Pocahontas (1995)',
#  'Poltergeist (1982)',
#  'Poseidon Adventure, The (1972)',
#  'Postman, The (Postino, Il) (1994)',
#  'Powder (1995)',
#  'Prestige, The (2006)',
#  'Pretty in Pink (1986)',
#  'Pride & Prejudice (2005)',
#  'Primal Fear (1996)',
#  'Prince of Egypt, The (1998)',
#  'Princess Bride, The (1987)',
#  'Princess Diaries, The (2001)',
#  'Producers, The (1968)',
#  'Prometheus (2012)',
#  'Psycho (1960)',
#  'Punch-Drunk Love (2002)',
#  'Pursuit of Happyness, The (2006)',
#  'Quantum of Solace (2008)',
#  'Quick and the Dead, The (1995)',
#  'Quiz Show (1994)',
#  'Raging Bull (1980)',
#  'Raising Arizona (1987)',
#  'Rambo: First Blood Part II (1985)',
#  'Ran (1985)',
#  'Rashomon (Rashômon) (1950)',
#  'Ratatouille (2007)',
#  'Ray (2004)',
#  'Reality Bites (1994)',
#  'Rear Window (1954)',
#  'Rebecca (1940)',
#  'Rebel Without a Cause (1955)',
#  'Red (2010)',
#  'Red Dragon (2002)',
#  'Red Violin, The (Violon rouge, Le) (1998)',
#  'Remains of the Day, The (1993)',
#  'Repo Man (1984)',
#  'Requiem for a Dream (2000)',
#  'Return of the Pink Panther, The (1975)',
#  'Richie Rich (1994)',
#  'Right Stuff, The (1983)',
#  'Rise of the Planet of the Apes (2011)',
#  'Risky Business (1983)',
#  'River Runs Through It, A (1992)',
#  'River Wild, The (1994)',
#  'Robin Hood (1973)',
#  'Robin Hood: Prince of Thieves (1991)',
#  'RoboCop 3 (1993)',
#  'Rocky (1976)',
#  'Rocky Horror Picture Show, The (1975)',
#  'Rocky II (1979)',
#  'Rocky III (1982)',
#  'Rocky IV (1985)',
#  'Roger & Me (1989)',
#  'Rogue One: A Star Wars Story (2016)',
#  'Roman Holiday (1953)',
#  "Romy and Michele's High School Reunion (1997)",
#  'Room with a View, A (1986)',
#  "Rosemary's Baby (1968)",
#  'Rumble in the Bronx (Hont faan kui) (1995)',
#  'Run Lola Run (Lola rennt) (1998)',
#  'Runaway Bride (1999)',
#  'Rushmore (1998)',
#  'Sabrina (1954)',
#  'Sabrina (1995)',
#  'Saint, The (1997)',
#  'Saw (2004)',
#  'Say Anything... (1989)',
#  'Scary Movie (2000)',
#  'Scary Movie 2 (2001)',
#  'School of Rock (2003)',
#  'Scott Pilgrim vs. the World (2010)',
#  'Scream 2 (1997)',
#  'Scream 3 (2000)',
#  'Seabiscuit (2003)',
#  'Searching for Bobby Fischer (1993)',
#  'Secret Garden, The (1993)',
#  'Secret of NIMH, The (1982)',
#  'Secretary (2002)',
#  'Secrets & Lies (1996)',
#  'Sense and Sensibility (1995)',
#  'Serenity (2005)',
#  'Serial Mom (1994)',
#  'Seven Samurai (Shichinin no samurai) (1954)',
#  'Seven Years in Tibet (1997)',
#  'Seventh Seal, The (Sjunde inseglet, Det) (1957)',
#  'Sex, Lies, and Videotape (1989)',
#  'Sgt. Bilko (1996)',
#  'Shadowlands (1993)',
#  'Shaft (2000)',
#  'Shakespeare in Love (1998)',
#  'Shallow Grave (1994)',
#  'Shanghai Noon (2000)',
#  "She's All That (1999)",
#  'Sherlock Holmes (2009)',
#  'Sherlock Holmes: A Game of Shadows (2011)',
#  'Shine (1996)',
#  'Shining, The (1980)',
#  'Short Cuts (1993)',
#  'Shutter Island (2010)',
#  'Sideways (2004)',
#  'Silver Linings Playbook (2012)',
#  'Simpsons Movie, The (2007)',
#  "Singin' in the Rain (1952)",
#  'Six Days Seven Nights (1998)',
#  'Six Degrees of Separation (1993)',
#  'Sixteen Candles (1984)',
#  'Skyfall (2012)',
#  'Sleeper (1973)',
#  'Sleepers (1996)',
#  'Sleeping Beauty (1959)',
#  'Sleepy Hollow (1999)',
#  'Sliding Doors (1998)',
#  'Sling Blade (1996)',
#  'Sliver (1993)',
#  'Slumdog Millionaire (2008)',
#  'Smoke (1995)',
#  'Snow White and the Seven Dwarfs (1937)',
#  'So I Married an Axe Murderer (1993)',
#  'Social Network, The (2010)',
#  'Some Like It Hot (1959)',
#  'Sound of Music, The (1965)',
#  'Source Code (2011)',
#  'Space Jam (1996)',
#  'Spartacus (1960)',
#  'Species (1995)',
#  'Speed 2: Cruise Control (1997)',
#  'Spider-Man 3 (2007)',
#  'Spirited Away (Sen to Chihiro no kamikakushi) (2001)',
#  'Spotlight (2015)',
#  'Spy Hard (1996)',
#  'Star Trek (2009)',
#  'Star Trek Into Darkness (2013)',
#  'Star Trek V: The Final Frontier (1989)',
#  'Star Trek: The Motion Picture (1979)',
#  'Star Wars: Episode VII - The Force Awakens (2015)',
#  'Stardust (2007)',
#  'Sting, The (1973)',
#  'Stir of Echoes (1999)',
#  'Stranger than Fiction (2006)',
#  'Strangers on a Train (1951)',
#  'Streetcar Named Desire, A (1951)',
#  'Strictly Ballroom (1992)',
#  'Stripes (1981)',
#  'Stuart Little (1999)',
#  'Sunset Blvd. (a.k.a. Sunset Boulevard) (1950)',
#  'Superbad (2007)',
#  'Superman III (1983)',
#  'Superman Returns (2006)',
#  'Sweeney Todd: The Demon Barber of Fleet Street (2007)',
#  'Swingers (1996)',
#  'Sword in the Stone, The (1963)',
#  'Taken (2008)',
#  'Talented Mr. Ripley, The (1999)',
#  'Tangled (2010)',
#  'Tarzan (1999)',
#  'Taxi Driver (1976)',
#  'Team America: World Police (2004)',
#  'Ted (2012)',
#  'Teenage Mutant Ninja Turtles (1990)',
#  'Terminal, The (2004)',
#  'Terms of Endearment (1983)',
#  'Thank You for Smoking (2006)',
#  'That Thing You Do! (1996)',
#  'The Butterfly Effect (2004)',
#  'The Hateful Eight (2015)',
#  'The Hobbit: The Battle of the Five Armies (2014)',
#  'The Hunger Games (2012)',
#  'The Hunger Games: Catching Fire (2013)',
#  'The Hunger Games: Mockingjay - Part 1 (2014)',
#  'The Imitation Game (2014)',
#  'The Lego Movie (2014)',
#  'The Machinist (2004)',
#  'The Martian (2015)',
#  'The Revenant (2015)',
#  'Thelma & Louise (1991)',
#  'There Will Be Blood (2007)',
#  'Thin Red Line, The (1998)',
#  'Thing, The (1982)',
#  'Third Man, The (1949)',
#  'This Is Spinal Tap (1984)',
#  'Thor (2011)',
#  'Three Colors: Blue (Trois couleurs: Bleu) (1993)',
#  'Three Colors: Red (Trois couleurs: Rouge) (1994)',
#  'Three Colors: White (Trzy kolory: Bialy) (1994)',
#  'Time Bandits (1981)',
#  'To Catch a Thief (1955)',
#  'To Wong Foo, Thanks for Everything! Julie Newmar (1995)',
#  'Tombstone (1993)',
#  'Tootsie (1982)',
#  'Touch of Evil (1958)',
#  'Toy Story 3 (2010)',
#  'Transporter, The (2002)',
#  'Treasure of the Sierra Madre, The (1948)',
#  'Tron: Legacy (2010)',
#  'Tropic Thunder (2008)',
#  'True Grit (2010)',
#  'True Romance (1993)',
#  'Truth About Cats & Dogs, The (1996)',
#  'Twilight (2008)',
#  'Unforgiven (1992)',
#  'Up (2009)',
#  'Up Close and Personal (1996)',
#  'Up in the Air (2009)',
#  'Vertigo (1958)',
#  'Village, The (2004)',
#  'Virgin Suicides, The (1999)',
#  'WALL·E (2008)',
#  'Waiting for Guffman (1996)',
#  'Waking Ned Devine (a.k.a. Waking Ned) (1998)',
#  'Walk in the Clouds, A (1995)',
#  'Walk the Line (2005)',
#  'Wall Street (1987)',
#  'Wallace & Gromit in The Curse of the Were-Rabbit (2005)',
#  'Wallace & Gromit: A Close Shave (1995)',
#  'Wallace & Gromit: The Best of Aardman Animation (1996)',
#  'Wallace & Gromit: The Wrong Trousers (1993)',
#  'Wanted (2008)',
#  'War of the Worlds (2005)',
#  'War of the Worlds, The (1953)',
#  'Watchmen (2009)',
#  'Waterworld (1995)',
#  'Wedding Planner, The (2001)',
#  'Wedding Singer, The (1998)',
#  'Weird Science (1985)',
#  'Welcome to the Dollhouse (1995)',
#  'West Side Story (1961)',
#  'What Dreams May Come (1998)',
#  'What Lies Beneath (2000)',
#  "What's Eating Gilbert Grape (1993)",
#  'When Harry Met Sally... (1989)',
#  'When a Man Loves a Woman (1994)',
#  'Whiplash (2014)',
#  'Willy Wonka & the Chocolate Factory (1971)',
#  'Witness (1985)',
#  'Wolf of Wall Street, The (2013)',
#  'Wonder Boys (2000)',
#  'Working Girl (1988)',
#  'World War Z (2013)',
#  'Wreck-It Ralph (2012)',
#  'Wrestler, The (2008)',
#  'Wyatt Earp (1994)',
#  'X-Men Origins: Wolverine (2009)',
#  'X-Men: Days of Future Past (2014)',
#  'X-Men: First Class (2011)',
#  'X-Men: The Last Stand (2006)',
#  'Yellow Submarine (1968)',
#  'Yes Man (2008)',
#  'Young Frankenstein (1974)',
#  'Young Guns (1988)',
#  'Zodiac (2007)',
#  'Zombieland (2009)',
#  'Zoolander (2001)',
#  'Zootopia (2016)']

# %%
# ratings distribution
user_ratings.value_counts(dropna=False)
# Out:
# NaN    1059
# 4.0      72
# 1.0      66
# 5.0      54
# 2.0      42
# 3.0      28
# 0.5      22
# 3.5       1
# Name: rating, dtype: int64

# %%
# user top movies
user_ratings.sort_values(ascending=False).head(20)
# Out:
# title
# Master and Commander: The Far Side of the World (2003)       5.0
# Day the Earth Stood Still, The (1951)                        5.0
# Blade Runner (1982)                                          5.0
# Matrix, The (1999)                                           5.0
# Lord of the Rings: The Two Towers, The (2002)                5.0
# Lord of the Rings: The Fellowship of the Ring, The (2001)    5.0
# Casino (1995)                                                5.0
# Jurassic Park (1993)                                         5.0
# Iron Man 2 (2010)                                            5.0
# Invasion of the Body Snatchers (1956)                        5.0
# Interstellar (2014)                                          5.0
# Inglourious Basterds (2009)                                  5.0
# Independence Day (a.k.a. ID4) (1996)                         5.0
# Dark City (1998)                                             5.0
# Dark Knight, The (2008)                                      5.0
# Dawn of the Dead (2004)                                      5.0
# Hunt for Red October, The (1990)                             5.0
# Planet of the Apes (1968)                                    5.0
# Die Hard (1988)                                              5.0
# District 9 (2009)                                            5.0
# Name: rating, dtype: float64

# %%
# user bottom movies
user_ratings.sort_values().head(20)
# Out:
# title
# Amelie (Fabuleux destin d'Amélie Poulain, Le) (2001)    0.5
# Grease (1978)                                           0.5
# Notebook, The (2004)                                    0.5
# How to Train Your Dragon (2010)                         0.5
# Titanic (1997)                                          0.5
# Frozen (2013)                                           0.5
# Toy Story 3 (2010)                                      0.5
# Harry Potter and the Goblet of Fire (2005)              0.5
# Sound of Music, The (1965)                              0.5
# It's a Wonderful Life (1946)                            0.5
# Twilight (2008)                                         0.5
# Meet Joe Black (1998)                                   0.5
# K-PAX (2001)                                            0.5
# Harry Potter and the Deathly Hallows: Part 2 (2011)     0.5
# Kung Fu Panda (2008)                                    0.5
# Princess Mononoke (Mononoke-hime) (1997)                0.5
# Lilo & Stitch (2002)                                    0.5
# Ratatouille (2007)                                      0.5
# William Shakespeare's Romeo + Juliet (1996)             0.5
# Corpse Bride (2005)                                     0.5
# Name: rating, dtype: float64

# %%
# user mean rating
user_mean = user_ratings.mean()
user_mean
# Out:
# 2.829824561403509

# %%
# user standard deviation rating
user_std = user_ratings.std()
user_std
# Out:
# 1.5960961300738952

# %%
user_zscores = (user_ratings-user_mean)/user_std
user_zscores
# Out:
# title
# (500) Days of Summer (2009)                              NaN
# 10 Things I Hate About You (1999)                        NaN
# 101 Dalmatians (1996)                                    NaN
# 101 Dalmatians (One Hundred and One Dalmatians) (1961)   NaN
# 12 Angry Men (1957)                                      NaN
#                                                           ..
# Zoolander (2001)                                         NaN
# Zootopia (2016)                                          NaN
# eXistenZ (1999)                                          NaN
# xXx (2002)                                               NaN
# ¡Three Amigos! (1986)                                    NaN
# Name: rating, Length: 1344, dtype: float64

# %% [markdown]
# ## The z-scores matrix

# %%
# matrix of z-scores (scale-free ratings)
z_scores = (ratings_matrix - ratings_matrix.mean())/ratings_matrix.std()
z_scores
# Out:
# userId                                                19        42      \
# title
# (500) Days of Summer (2009)                              NaN  0.441226
# 10 Things I Hate About You (1999)                        NaN       NaN
# 101 Dalmatians (1996)                                    NaN  0.441226
# 101 Dalmatians (One Hundred and One Dalmatians)...       NaN       NaN
# 12 Angry Men (1957)                                 1.905267       NaN
# ...                                                      ...       ...
# Zoolander (2001)                                         NaN       NaN
# Zootopia (2016)                                          NaN       NaN
# eXistenZ (1999)                                          NaN       NaN
# xXx (2002)                                               NaN       NaN
# ¡Three Amigos! (1986)                                    NaN       NaN
#
# userId                                                43        51      \
# title
# (500) Days of Summer (2009)                              NaN       NaN
# 10 Things I Hate About You (1999)                        NaN       NaN
# 101 Dalmatians (1996)                                    NaN       NaN
# 101 Dalmatians (One Hundred and One Dalmatians)...       NaN       NaN
# 12 Angry Men (1957)                                 0.523548  1.245453
# ...                                                      ...       ...
# Zoolander (2001)                                         NaN       NaN
# Zootopia (2016)                                          NaN       NaN
# eXistenZ (1999)                                          NaN       NaN
# xXx (2002)                                               NaN       NaN
# ¡Three Amigos! (1986)                              -1.942640 -0.945344
#
# userId                                                55        56      \
# title
# (500) Days of Summer (2009)                              NaN       NaN
# 10 Things I Hate About You (1999)                  -1.913005       NaN
# 101 Dalmatians (1996)                                    NaN -2.040622
# 101 Dalmatians (One Hundred and One Dalmatians)... -0.111992 -1.576142
# 12 Angry Men (1957)                                      NaN  1.210739
# ...                                                      ...       ...
# Zoolander (2001)                                         NaN -0.182702
# Zootopia (2016)                                          NaN       NaN
# eXistenZ (1999)                                          NaN       NaN
# xXx (2002)                                               NaN       NaN
# ¡Three Amigos! (1986)                                    NaN       NaN
#
# userId                                                71        73      \
# title
# (500) Days of Summer (2009)                        -1.447012  0.883303
# 10 Things I Hate About You (1999)                        NaN       NaN
# 101 Dalmatians (1996)                                    NaN       NaN
# 101 Dalmatians (One Hundred and One Dalmatians)...       NaN       NaN
# 12 Angry Men (1957)                                      NaN       NaN
# ...                                                      ...       ...
# Zoolander (2001)                                         NaN -1.694737
# Zootopia (2016)                                          NaN       NaN
# eXistenZ (1999)                                          NaN       NaN
# xXx (2002)                                               NaN       NaN
# ¡Three Amigos! (1986)                                    NaN       NaN
#
# userId                                                79        81      ...  \
# title                                                                   ...
# (500) Days of Summer (2009)                              NaN -0.337638  ...
# 10 Things I Hate About You (1999)                  -0.311645 -0.337638  ...
# 101 Dalmatians (1996)                                    NaN       NaN  ...
# 101 Dalmatians (One Hundred and One Dalmatians)...       NaN       NaN  ...
# 12 Angry Men (1957)                                      NaN  1.501957  ...
# ...                                                      ...       ...  ...
# Zoolander (2001)                                         NaN -0.337638  ...
# Zootopia (2016)                                          NaN       NaN  ...
# eXistenZ (1999)                                          NaN       NaN  ...
# xXx (2002)                                               NaN -2.637132  ...
# ¡Three Amigos! (1986)                                    NaN       NaN  ...
#
# userId                                                283153  283164  \
# title
# (500) Days of Summer (2009)                              NaN     NaN
# 10 Things I Hate About You (1999)                   0.197451     NaN
# 101 Dalmatians (1996)                                    NaN     NaN
# 101 Dalmatians (One Hundred and One Dalmatians)...       NaN     NaN
# 12 Angry Men (1957)                                      NaN     NaN
# ...                                                      ...     ...
# Zoolander (2001)                                    0.197451     NaN
# Zootopia (2016)                                          NaN     NaN
# eXistenZ (1999)                                          NaN     NaN
# xXx (2002)                                         -1.652619     NaN
# ¡Three Amigos! (1986)                                    NaN     NaN
#
# userId                                                283165    283170  \
# title
# (500) Days of Summer (2009)                              NaN -0.552253
# 10 Things I Hate About You (1999)                   1.846808       NaN
# 101 Dalmatians (1996)                                    NaN       NaN
# 101 Dalmatians (One Hundred and One Dalmatians)...       NaN       NaN
# 12 Angry Men (1957)                                 0.006166       NaN
# ...                                                      ...       ...
# Zoolander (2001)                                         NaN       NaN
# Zootopia (2016)                                          NaN       NaN
# eXistenZ (1999)                                          NaN       NaN
# xXx (2002)                                               NaN       NaN
# ¡Three Amigos! (1986)                                    NaN       NaN
#
# userId                                              283183    283184  \
# title
# (500) Days of Summer (2009)                            NaN  0.258297
# 10 Things I Hate About You (1999)                      NaN       NaN
# 101 Dalmatians (1996)                                  NaN       NaN
# 101 Dalmatians (One Hundred and One Dalmatians)...     NaN       NaN
# 12 Angry Men (1957)                                    NaN       NaN
# ...                                                    ...       ...
# Zoolander (2001)                                       NaN -1.559117
# Zootopia (2016)                                        NaN       NaN
# eXistenZ (1999)                                        NaN       NaN
# xXx (2002)                                             NaN       NaN
# ¡Three Amigos! (1986)                                  NaN       NaN
#
# userId                                                283185    283195  \
# title
# (500) Days of Summer (2009)                              NaN       NaN
# 10 Things I Hate About You (1999)                        NaN -1.542636
# 101 Dalmatians (1996)                                    NaN       NaN
# 101 Dalmatians (One Hundred and One Dalmatians)... -0.538664  0.772019
# 12 Angry Men (1957)                                      NaN       NaN
# ...                                                      ...       ...
# Zoolander (2001)                                         NaN -0.385309
# Zootopia (2016)                                          NaN       NaN
# eXistenZ (1999)                                          NaN       NaN
# xXx (2002)                                               NaN       NaN
# ¡Three Amigos! (1986)                                    NaN  0.772019
#
# userId                                              283204    283224
# title
# (500) Days of Summer (2009)                            NaN       NaN
# 10 Things I Hate About You (1999)                      NaN       NaN
# 101 Dalmatians (1996)                                  NaN       NaN
# 101 Dalmatians (One Hundred and One Dalmatians)...     NaN       NaN
# 12 Angry Men (1957)                                    NaN  1.290966
# ...                                                    ...       ...
# Zoolander (2001)                                       NaN       NaN
# Zootopia (2016)                                        NaN       NaN
# eXistenZ (1999)                                        NaN       NaN
# xXx (2002)                                             NaN       NaN
# ¡Three Amigos! (1986)                                  NaN       NaN
#
# [1344 rows x 35288 columns]

# %% [markdown]
# ## Similarities

# %%
# user similarity function = correlation 
similarities = z_scores.corrwith(user_zscores)
similarities
# Out:
# userId
# 19       -0.049808
# 42        0.205664
# 43        0.016950
# 51       -0.112660
# 55       -0.001891
#             ...
# 283184   -0.125203
# 283185   -0.374497
# 283195   -0.048138
# 283204    0.150890
# 283224    0.334381
# Length: 35288, dtype: float64

# %% [markdown]
# ## Prediction function

# %%
# select number of neighbors
k = 10

# select an (unrated) item: 'Dawn of the Dead (2004)', "Zoolander (2001)", 'Duck Soup (1933)'
item = 'Zoolander (2001)'

# %%
# k nearest neighbors similarities
knn_sim = similarities[ratings_matrix.loc[item].notna()].sort_values(ascending=False).head(k)
knn_sim
# Out:
# userId
# 269669    0.258772
# 29146     0.254204
# 107938    0.248449
# 131845    0.231966
# 60705     0.225157
# 26732     0.217312
# 232485    0.216629
# 253654    0.208472
# 133855    0.205827
# 44185     0.204255
# dtype: float64

# %%
# normalization factor
total = knn_sim.abs().sum()
total
# Out:
# 2.271044676052669

# %%
# k nearest neighbors
knn = knn_sim.index
knn
# Out:
# Int64Index([269669, 29146, 107938, 131845, 60705, 26732, 232485, 253654,
#             133855, 44185],
#            dtype='int64', name='userId')

# %%
knn_z_scores = z_scores.loc[item,knn]
knn_z_scores
# Out:
# userId
# 269669    0.034749
# 29146    -0.476857
# 107938   -0.632292
# 131845    0.798012
# 60705     0.140083
# 26732     0.510159
# 232485    0.869412
# 253654   -2.299054
# 133855    0.836761
# 44185    -0.389261
# Name: Zoolander (2001), dtype: float64

# %%
# prediction
prediction = user_mean + user_std*knn_z_scores.dot(knn_sim)/total
print(item+': '+str(np.round(prediction,1)))
# Out:
# Zoolander (2001): 2.7

# %%
# the same in one cell:

# select number of neighbors
k = 10

# select item
item = "Blair Witch Project, The (1999)"# 

# k nearest neighbors similarities
knn_sim = similarities[ratings_matrix.loc[item].notna()].sort_values(ascending=False).head(k)
    
# normalization factor
total = knn_sim.abs().sum()

# k nearest neighbors
knn = knn_sim.index

# k nearest neighbors z-scores
knn_z_scores = z_scores.loc[item,knn]

# prediction
prediction = user_mean + user_std*knn_sim.dot(knn_z_scores)/total

print(item+': '+str(np.round(prediction,1)))
# Out:
# Blair Witch Project, The (1999): 2.4

# %% [markdown]
# Let us predict the ratings for all unrated movies.

# %%
# unrated movies
unrated_movies = user_ratings[user_ratings.isna()].index
unrated_movies
# Out:
# Index(['(500) Days of Summer (2009)', '10 Things I Hate About You (1999)',
#        '101 Dalmatians (1996)',
#        '101 Dalmatians (One Hundred and One Dalmatians) (1961)',
#        '12 Angry Men (1957)', '12 Years a Slave (2013)', '127 Hours (2010)',
#        '13 Going on 30 (2004)', '13th Warrior, The (1999)',
#        '2 Fast 2 Furious (Fast and the Furious 2, The) (2003)',
#        ...
#        'You've Got Mail (1998)', 'Young Frankenstein (1974)',
#        'Young Guns (1988)', 'Zodiac (2007)', 'Zombieland (2009)',
#        'Zoolander (2001)', 'Zootopia (2016)', 'eXistenZ (1999)', 'xXx (2002)',
#        '¡Three Amigos! (1986)'],
#       dtype='object', name='title', length=1344)

# %%
user_ratings_pred = pd.Series(index=unrated_movies)
user_ratings_pred
# Out:
# C:\Users\javier.perez-alvaro\AppData\Local\Temp\ipykernel_29520\3009066579.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   user_ratings_pred = pd.Series(index=unrated_movies)
# title
# (500) Days of Summer (2009)                              NaN
# 10 Things I Hate About You (1999)                        NaN
# 101 Dalmatians (1996)                                    NaN
# 101 Dalmatians (One Hundred and One Dalmatians) (1961)   NaN
# 12 Angry Men (1957)                                      NaN
#                                                           ..
# Zoolander (2001)                                         NaN
# Zootopia (2016)                                          NaN
# eXistenZ (1999)                                          NaN
# xXx (2002)                                               NaN
# ¡Three Amigos! (1986)                                    NaN
# Length: 1344, dtype: float64

# %%
for item in unrated_movies:
    knn_sim = similarities[ratings_matrix.loc[item].notna()].sort_values(ascending=False).head(k)

    # normalization factor
    total = knn_sim.abs().sum()

    # k nearest neighbors
    knn = knn_sim.index

    # k nearest neighbors z-scores
    knn_z_scores = z_scores.loc[item,knn]

    # prediction
    user_ratings_pred[item] = user_mean + user_std*knn_sim.dot(knn_z_scores)/total

# %%
# top 20 recommendations
user_ratings_pred.sort_values(ascending=False).head(20)
# Out:
# title
# Star Wars: Episode V - The Empire Strikes Back (1980)             4.564217
# American History X (1998)                                         4.395307
# Ghost in the Shell (Kôkaku kidôtai) (1995)                        4.372755
# Departed, The (2006)                                              4.365995
# Lord of the Rings: The Return of the King, The (2003)             4.311291
# L.A. Confidential (1997)                                          4.293398
# Once Upon a Time in the West (C'era una volta il West) (1968)     4.289093
# Sting, The (1973)                                                 4.248143
# Highlander (1986)                                                 4.246966
# Matrix Revolutions, The (2003)                                    4.240243
# Predator (1987)                                                   4.219169
# Heat (1995)                                                       4.214763
# Name of the Rose, The (Name der Rose, Der) (1986)                 4.207828
# John Wick (2014)                                                  4.198841
# Léon: The Professional (a.k.a. The Professional) (Léon) (1994)    4.195914
# Usual Suspects, The (1995)                                        4.195837
# Sixth Sense, The (1999)                                           4.178050
# Nightcrawler (2014)                                               4.176968
# Great Escape, The (1963)                                          4.163868
# Guardians of the Galaxy (2014)                                    4.156052
# dtype: float64

# %%
# bottom 20 recommendations
user_ratings_pred.sort_values(ascending=False).tail(20)
# Out:
# title
# Casper (1995)                                             0.699906
# Cinderella (1950)                                         0.698094
# Prince of Egypt, The (1998)                               0.680200
# Honey, I Blew Up the Kid (1992)                           0.619627
# Beauty and the Beast (1991)                               0.607981
# Sleeping Beauty (1959)                                    0.606085
# Legally Blonde (2001)                                     0.576095
# Lady and the Tramp (1955)                                 0.566534
# Snow White and the Seven Dwarfs (1937)                    0.545692
# Miracle on 34th Street (1994)                             0.529628
# 13 Going on 30 (2004)                                     0.473137
# Spy Kids (2001)                                           0.444618
# James and the Giant Peach (1996)                          0.431036
# Babe (1995)                                               0.426545
# 101 Dalmatians (One Hundred and One Dalmatians) (1961)    0.319163
# Hunchback of Notre Dame, The (1996)                       0.244507
# Super Mario Bros. (1993)                                  0.066326
# Babe: Pig in the City (1998)                             -0.038262
# Brokeback Mountain (2005)                                -0.152378
# Free Willy (1993)                                        -0.188147
# dtype: float64

# %% [markdown]
# ## How good are the predictions?

# %%
user_ratings = user_ratings.to_frame('rating')
user_ratings['prediction'] = np.NaN
user_ratings
# Out:
#                                                     rating  prediction
# title
# (500) Days of Summer (2009)                            NaN         NaN
# 10 Things I Hate About You (1999)                      NaN         NaN
# 101 Dalmatians (1996)                                  NaN         NaN
# 101 Dalmatians (One Hundred and One Dalmatians)...     NaN         NaN
# 12 Angry Men (1957)                                    NaN         NaN
# ...                                                    ...         ...
# Zoolander (2001)                                       NaN         NaN
# Zootopia (2016)                                        NaN         NaN
# eXistenZ (1999)                                        NaN         NaN
# xXx (2002)                                             NaN         NaN
# ¡Three Amigos! (1986)                                  NaN         NaN
#
# [1344 rows x 2 columns]

# %%
# predict rating for each movie (regardless of whether the movie has been rated or not)
k = 10
for item in user_ratings.index:
    knn_sim = similarities[ratings_matrix.loc[item].notna()].sort_values(ascending=False).head(k)

    # normalization factor
    total = knn_sim.abs().sum()

    # k nearest neighbors
    knn = knn_sim.index

    # k nearest neighbors z-scores
    knn_z_scores = z_scores.loc[item,knn]

    # prediction
    user_ratings.loc[item,'prediction'] = user_mean + user_std*knn_sim.dot(knn_z_scores)/total

# %%
user_ratings
# Out:
#                                                     rating  prediction  error
# title
# (500) Days of Summer (2009)                            NaN    2.893449    NaN
# 10 Things I Hate About You (1999)                      NaN    2.021918    NaN
# 101 Dalmatians (1996)                                  NaN    0.586101    NaN
# 101 Dalmatians (One Hundred and One Dalmatians)...     NaN    1.414559    NaN
# 12 Angry Men (1957)                                    NaN    3.324799    NaN
# ...                                                    ...         ...    ...
# Zoolander (2001)                                       NaN    2.731409    NaN
# Zootopia (2016)                                        NaN    1.220095    NaN
# eXistenZ (1999)                                        NaN    2.710197    NaN
# xXx (2002)                                             NaN    1.244820    NaN
# ¡Three Amigos! (1986)                                  NaN    2.624933    NaN
#
# [1344 rows x 3 columns]

# %%
# prediction error
user_ratings['error'] = user_ratings.rating - user_ratings.prediction
user_ratings
# Out:
#                                                     rating  prediction  error
# title
# (500) Days of Summer (2009)                            NaN    2.893449    NaN
# 10 Things I Hate About You (1999)                      NaN    2.021918    NaN
# 101 Dalmatians (1996)                                  NaN    0.586101    NaN
# 101 Dalmatians (One Hundred and One Dalmatians)...     NaN    1.414559    NaN
# 12 Angry Men (1957)                                    NaN    3.324799    NaN
# ...                                                    ...         ...    ...
# Zoolander (2001)                                       NaN    2.731409    NaN
# Zootopia (2016)                                        NaN    1.220095    NaN
# eXistenZ (1999)                                        NaN    2.710197    NaN
# xXx (2002)                                             NaN    1.244820    NaN
# ¡Three Amigos! (1986)                                  NaN    2.624933    NaN
#
# [1344 rows x 3 columns]

# %%
# error histogram
user_ratings.loc[user_ratings.error.notna(),'error'].hist()
# Out:
# <AxesSubplot:>

# %%
# (square root of the) mean squared error
num_unrated_movies = user_ratings.rating.isna().sum()
np.sqrt((user_ratings.loc[user_ratings.error.notna(),'error']**2).sum()/num_unrated_movies)
# Out:
# 0.5331978551376553

# %% [markdown]
# ## Selecting the number of neighbors (k)

# %%
user_ratings
# Out:
#                                                     rating  prediction  error
# title
# (500) Days of Summer (2009)                            NaN    2.893449    NaN
# 10 Things I Hate About You (1999)                      NaN    2.021918    NaN
# 101 Dalmatians (1996)                                  NaN    0.586101    NaN
# 101 Dalmatians (One Hundred and One Dalmatians)...     NaN    1.414559    NaN
# 12 Angry Men (1957)                                    NaN    3.324799    NaN
# ...                                                    ...         ...    ...
# Zoolander (2001)                                       NaN    2.731409    NaN
# Zootopia (2016)                                        NaN    1.220095    NaN
# eXistenZ (1999)                                        NaN    2.710197    NaN
# xXx (2002)                                             NaN    1.244820    NaN
# ¡Three Amigos! (1986)                                  NaN    2.624933    NaN
#
# [1344 rows x 3 columns]

# %%
k_list = np.arange(1,50)
errors = np.zeros(len(k_list))
num_unrated_movies = user_ratings.rating.isna().sum()

for i in range(len(k_list)):
    k = k_list[i]
    # predict ratings
    for item in user_ratings.index:
        knn_sim = similarities[ratings_matrix.loc[item].notna()].sort_values(ascending=False).head(k)

        # normalization factor
        total = knn_sim.abs().sum()

        # k nearest neighbors
        knn = knn_sim.index

        # k nearest neighbors z-scores
        knn_z_scores = z_scores.loc[item,knn]

        # prediction
        user_ratings.loc[item,'prediction'] = user_mean + user_std*knn_sim.dot(knn_z_scores)/total
        
    # error
    user_ratings['error'] = user_ratings.rating - user_ratings.prediction    
    # compute mean squared error
    errors[i] = np.sqrt((user_ratings.loc[user_ratings.error.notna(),'error']**2).sum()/num_unrated_movies)

# %%
plt.plot(k_list,errors,'o--')
plt.xlabel('number of neighbors k')
plt.ylabel('prediction error')

# %% [markdown]
# ## The impact of the long tail

# %%
# number of ratings each movie received
n_ratings = ratings.groupby('title')['rating'].count()
n_ratings
# Out:
# title
# (500) Days of Summer (2009)                               6030
# 10 Things I Hate About You (1999)                         8385
# 101 Dalmatians (1996)                                     5327
# 101 Dalmatians (One Hundred and One Dalmatians) (1961)    6326
# 12 Angry Men (1957)                                       9469
#                                                           ...
# Zoolander (2001)                                          8618
# Zootopia (2016)                                           4031
# eXistenZ (1999)                                           4437
# xXx (2002)                                                5112
# ¡Three Amigos! (1986)                                     5166
# Name: rating, Length: 1344, dtype: int64

# %%
n_ratings.plot.hist(bins=20)
plt.xlabel('number of ratings')
plt.ylabel('number of movies')
# Out:
# Text(0, 0.5, 'number of movies')

# %%
# popular movies
n_ratings[n_ratings>20000].sort_values(ascending=False)
# Out:
# title
# Forrest Gump (1994)                                                               29095
# Matrix, The (1999)                                                                28917
# Pulp Fiction (1994)                                                               28128
# Star Wars: Episode IV - A New Hope (1977)                                         27398
# Silence of the Lambs, The (1991)                                                  26916
# Shawshank Redemption, The (1994)                                                  26635
# Star Wars: Episode V - The Empire Strikes Back (1980)                             26582
# Jurassic Park (1993)                                                              26423
# Back to the Future (1985)                                                         26305
# Raiders of the Lost Ark (Indiana Jones and the Raiders of the Lost Ark) (1981)    25597
# Star Wars: Episode VI - Return of the Jedi (1983)                                 25334
# Toy Story (1995)                                                                  24652
# Men in Black (a.k.a. MIB) (1997)                                                  24526
# Terminator 2: Judgment Day (1991)                                                 24478
# American Beauty (1999)                                                            24288
# Sixth Sense, The (1999)                                                           24144
# Fight Club (1999)                                                                 24028
# Lord of the Rings: The Fellowship of the Ring, The (2001)                         23921
# Braveheart (1995)                                                                 23684
# Groundhog Day (1993)                                                              23093
# Terminator, The (1984)                                                            23032
# Independence Day (a.k.a. ID4) (1996)                                              22988
# Saving Private Ryan (1998)                                                        22796
# Seven (a.k.a. Se7en) (1995)                                                       22714
# Gladiator (2000)                                                                  22690
# Usual Suspects, The (1995)                                                        22613
# Lord of the Rings: The Two Towers, The (2002)                                     22176
# Fargo (1996)                                                                      22092
# Godfather, The (1972)                                                             22083
# Shrek (2001)                                                                      22041
# Schindler's List (1993)                                                           22005
# Indiana Jones and the Last Crusade (1989)                                         21933
# Die Hard (1988)                                                                   21438
# E.T. the Extra-Terrestrial (1982)                                                 21373
# Alien (1979)                                                                      21169
# Titanic (1997)                                                                    21156
# Twelve Monkeys (a.k.a. 12 Monkeys) (1995)                                         21085
# Monty Python and the Holy Grail (1975)                                            20984
# Lord of the Rings: The Return of the King, The (2003)                             20972
# Truman Show, The (1998)                                                           20916
# Ghostbusters (a.k.a. Ghost Busters) (1984)                                        20759
# Good Will Hunting (1997)                                                          20599
# Fifth Element, The (1997)                                                         20556
# Blade Runner (1982)                                                               20410
# Speed (1994)                                                                      20261
# Star Wars: Episode I - The Phantom Menace (1999)                                  20163
# Memento (2000)                                                                    20115
# Name: rating, dtype: int64

# %%
# number of users
n_users = ratings['userId'].nunique()
n_users
# Out:
# 35289

# %%
# weights
weights = np.log(n_users/n_ratings)
weights
# Out:
# title
# (500) Days of Summer (2009)                               1.766824
# 10 Things I Hate About You (1999)                         1.437127
# 101 Dalmatians (1996)                                     1.890783
# 101 Dalmatians (One Hundred and One Dalmatians) (1961)    1.718903
# 12 Angry Men (1957)                                       1.315548
#                                                             ...
# Zoolander (2001)                                          1.409718
# Zootopia (2016)                                           2.169557
# eXistenZ (1999)                                           2.073593
# xXx (2002)                                                1.931981
# ¡Three Amigos! (1986)                                     1.921473
# Name: rating, Length: 1344, dtype: float64

# %%
weights['Matrix, The (1999)']
# Out:
# 0.19914164317647326

# %%
weights['Dark City (1998)']
# Out:
# 1.3463262548193837

# %%
# pandas does not have a built-in function that computes weighted correlations
def weighted_corrwith(y):
    # computes weighted correlation between x and y
    
    x = user_zscores
    
    # means
    mean_x = np.mean(x)
    mean_y = np.mean(y)
    
    # denominator
    den1 = np.sqrt(np.sum((weights*(x-mean_x)**2)))
    den2 = np.sqrt(np.sum((weights*(y-mean_y)**2)))
    den = den1*den2
    
    # numerator
    num = np.sum(weights*(x-mean_x)*(y-mean_y))
    
    return num/den

# %%
# weighted similarities
similarities = z_scores.apply(weighted_corrwith)
similarities
# Out:
# C:\Users\javier.perez-alvaro\AppData\Local\Temp\ipykernel_29520\933562684.py:19: RuntimeWarning: invalid value encountered in double_scalars
#   return num/den
# userId
# 19        0.004222
# 42        0.025606
# 43       -0.009501
# 51       -0.032180
# 55        0.009073
#             ...
# 283184   -0.043505
# 283185   -0.027653
# 283195   -0.035021
# 283204    0.003724
# 283224    0.036143
# Length: 35288, dtype: float64

# %%
user_ratings['prediction 2'] = np.NaN
user_ratings
# Out:
#                                                     rating  prediction  error  \
# title
# (500) Days of Summer (2009)                            NaN    2.176663    NaN
# 10 Things I Hate About You (1999)                      NaN    1.568083    NaN
# 101 Dalmatians (1996)                                  NaN    0.793997    NaN
# 101 Dalmatians (One Hundred and One Dalmatians)...     NaN    0.319163    NaN
# 12 Angry Men (1957)                                    NaN    2.554362    NaN
# ...                                                    ...         ...    ...
# Zoolander (2001)                                       NaN    2.252833    NaN
# Zootopia (2016)                                        NaN    1.325693    NaN
# eXistenZ (1999)                                        NaN    3.049560    NaN
# xXx (2002)                                             NaN    2.535764    NaN
# ¡Three Amigos! (1986)                                  NaN    2.121858    NaN
#
#                                                     prediction 2
# title
# (500) Days of Summer (2009)                                  NaN
# 10 Things I Hate About You (1999)                            NaN
# 101 Dalmatians (1996)                                        NaN
# 101 Dalmatians (One Hundred and One Dalmatians)...           NaN
# 12 Angry Men (1957)                                          NaN
# ...                                                          ...
# Zoolander (2001)                                             NaN
# Zootopia (2016)                                              NaN
# eXistenZ (1999)                                              NaN
# xXx (2002)                                                   NaN
# ¡Three Amigos! (1986)                                        NaN
#
# [1344 rows x 4 columns]

# %%
# predict rating for each movie (regardless of whether the movie has been rated or not)
k = 10
for item in user_ratings.index:
    knn_sim = similarities[ratings_matrix.loc[item].notna()].sort_values(ascending=False).head(k)

    # normalization factor
    total = knn_sim.abs().sum()

    # k nearest neighbors
    knn = knn_sim.index

    # k nearest neighbors z-scores
    knn_z_scores = z_scores.loc[item,knn]

    # prediction
    user_ratings.loc[item,'prediction 2'] = user_mean + user_std*knn_sim.dot(knn_z_scores)/total

# %%
user_ratings
# Out:
#                                                     rating  prediction  error  \
# title
# (500) Days of Summer (2009)                            NaN    2.176663    NaN
# 10 Things I Hate About You (1999)                      NaN    1.568083    NaN
# 101 Dalmatians (1996)                                  NaN    0.793997    NaN
# 101 Dalmatians (One Hundred and One Dalmatians)...     NaN    0.319163    NaN
# 12 Angry Men (1957)                                    NaN    2.554362    NaN
# ...                                                    ...         ...    ...
# Zoolander (2001)                                       NaN    2.252833    NaN
# Zootopia (2016)                                        NaN    1.325693    NaN
# eXistenZ (1999)                                        NaN    3.049560    NaN
# xXx (2002)                                             NaN    2.535764    NaN
# ¡Three Amigos! (1986)                                  NaN    2.121858    NaN
#
#                                                     prediction 2
# title
# (500) Days of Summer (2009)                             2.893449
# 10 Things I Hate About You (1999)                       2.021918
# 101 Dalmatians (1996)                                   0.586101
# 101 Dalmatians (One Hundred and One Dalmatians)...      1.414559
# 12 Angry Men (1957)                                     3.324799
# ...                                                          ...
# Zoolander (2001)                                        2.731409
# Zootopia (2016)                                         1.220095
# eXistenZ (1999)                                         2.710197
# xXx (2002)                                              1.244820
# ¡Three Amigos! (1986)                                   2.624933
#
# [1344 rows x 4 columns]

# %%
# top 20 recommendations 
user_ratings.loc[user_ratings.rating.isna(),'prediction 2'].sort_values(ascending=False).head(20)
# Out:
# title
# Star Wars: Episode IV - A New Hope (1977)                4.733631
# Usual Suspects, The (1995)                               4.646547
# Star Wars: Episode V - The Empire Strikes Back (1980)    4.617198
# Dark Knight Rises, The (2012)                            4.575422
# Evil Dead II (Dead by Dawn) (1987)                       4.563789
# Taxi Driver (1976)                                       4.507718
# Army of Darkness (1993)                                  4.476801
# Thing, The (1982)                                        4.468586
# Heat (1995)                                              4.449924
# Great Escape, The (1963)                                 4.352469
# American History X (1998)                                4.303639
# Back to the Future (1985)                                4.300234
# Watchmen (2009)                                          4.277845
# Departed, The (2006)                                     4.271043
# Deadpool (2016)                                          4.260674
# Star Wars: Episode VI - Return of the Jedi (1983)        4.256805
# Donnie Darko (2001)                                      4.253474
# Nightcrawler (2014)                                      4.237381
# Office Space (1999)                                      4.217532
# Doors, The (1991)                                        4.210320
# Name: prediction 2, dtype: float64

# %%
# bottom  20 recommendations 
user_ratings.loc[user_ratings.rating.isna(),'prediction 2'].sort_values(ascending=False).tail(20)
# Out:
# title
# Secret Garden, The (1993)                                  0.799150
# Tangled (2010)                                             0.778906
# Chicago (2002)                                             0.726402
# 28 Days (2000)                                             0.664304
# Richie Rich (1994)                                         0.662105
# Honey, I Blew Up the Kid (1992)                            0.636604
# Babe: Pig in the City (1998)                               0.627670
# Striptease (1996)                                          0.591334
# 101 Dalmatians (1996)                                      0.586101
# To Wong Foo, Thanks for Everything! Julie Newmar (1995)    0.571428
# Emperor's New Groove, The (2000)                           0.568319
# Casper (1995)                                              0.560985
# Beauty and the Beast (1991)                                0.501294
# Evita (1996)                                               0.492087
# Scary Movie 2 (2001)                                       0.487258
# Spy Kids (2001)                                            0.461289
# Sense and Sensibility (1995)                               0.439508
# Super Mario Bros. (1993)                                   0.416619
# Ever After: A Cinderella Story (1998)                      0.374232
# Wedding Planner, The (2001)                                0.314331
# Name: prediction 2, dtype: float64

# %%
user_ratings.loc['Twilight (2008)']
# Out:
# rating          0.500000
# prediction     -0.451343
# error           0.951343
# prediction 2   -0.205214
# Name: Twilight (2008), dtype: float64

# %% [markdown]
# ## Appendix: create a fake user

# %%
fake_user = pd.DataFrame(index=ratings_matrix.index,columns=['rating'])
fake_user

# %%
fake_user.to_csv('fake_kid_user.csv')
