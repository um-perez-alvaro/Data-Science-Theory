# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# **Contents**
#
# - [Latent Factor Model](#1.-Latent-Factor-Model)
# - [Incorporating User and item biases](#2.-Incorporating-user-and-item-biases)
# - [Another fake user]()

# %% [markdown]
# ## 1. Latent Factor Model

# %%
def latent_factor_model(R, k, learning_rate, n_epochs):
    m, n = R.shape
    
    # number of nonzero ratings
    n_zero_ratings = np.sum(~np.isnan(R))
    
    # initialization
    U = np.random.randn(m,k)
    V = np.random.randn(n,k)
    
    mean_error = np.zeros(n_epochs)
    
    # gradient descent steps
    for i in range(n_epochs):
        
        # error matrix
        E = R-U.dot(V.T)
        E[np.isnan(E)]=0

        # update U and V
        new_U = U + learning_rate*E.dot(V)
        new_V = V + learning_rate*E.T.dot(U)

        U = new_U
        V = new_V
        
        # compute mean_error
        error_squared = np.sum(E**2)
        mean_error[i] = np.sqrt(error_squared/(n_zero_ratings))
        
    return U, V, mean_error

# %% [markdown]
# **Simple example**

# %%
R = np.array([
    [2, np.nan, 3, np.nan],
    [np.nan, 5, np.nan, 4],
    [1, 3, np.nan, 5],
    [np.nan, 4, 2, np.nan]
])
R
# Out:
# array([[ 2., nan,  3., nan],
#        [nan,  5., nan,  4.],
#        [ 1.,  3., nan,  5.],
#        [nan,  4.,  2., nan]])

# %%
U, V, mean_error = latent_factor_model(R, 
                                       k = 2,
                                       learning_rate = 0.05,
                                       n_epochs = 50)

# %%
plt.plot(mean_error)

# %%
R
# Out:
# array([[ 2., nan,  3., nan],
#        [nan,  5., nan,  4.],
#        [ 1.,  3., nan,  5.],
#        [nan,  4.,  2., nan]])

# %%
# approximation of R
U.dot(V.T).round(2)
# Out:
# array([[ 1.91,  2.5 ,  3.03, -1.09],
#        [ 2.43,  4.97, -0.41,  4.02],
#        [ 0.92,  3.04, -2.89,  4.99],
#        [ 2.45,  4.01,  1.98,  1.02]])

# %% [markdown]
# **MoviLens dataset example**

# %%
ratings = pd.read_csv('ratings_large.csv')
ratings.head()
# Out:
#    userId  movieId  rating   timestamp                               title
# 0       4        1     4.0  1113765937                    Toy Story (1995)
# 1       4        2     4.0  1113767306                      Jumanji (1995)
# 2       4        5     2.0  1123990453  Father of the Bride Part II (1995)
# 3       4        6     4.5  1113767242                         Heat (1995)
# 4       4       10     4.0  1113765995                    GoldenEye (1995)

# %%
# ratings matrix
ratings_matrix = ratings.pivot('title','userId')['rating']
ratings_matrix
# Out:
# userId                                              4       19      42      \
# title
# (500) Days of Summer (2009)                            NaN     NaN     4.0
# 10 Things I Hate About You (1999)                      NaN     NaN     NaN
# 101 Dalmatians (1996)                                  NaN     NaN     4.0
# 101 Dalmatians (One Hundred and One Dalmatians)...     NaN     NaN     NaN
# 12 Angry Men (1957)                                    1.5     5.0     NaN
# ...                                                    ...     ...     ...
# Zoolander (2001)                                       NaN     NaN     NaN
# Zootopia (2016)                                        NaN     NaN     NaN
# eXistenZ (1999)                                        3.5     NaN     NaN
# xXx (2002)                                             3.5     NaN     NaN
# ¡Three Amigos! (1986)                                  3.0     NaN     NaN
#
# userId                                              43      51      55      \
# title
# (500) Days of Summer (2009)                            NaN     NaN     NaN
# 10 Things I Hate About You (1999)                      NaN     NaN     1.5
# 101 Dalmatians (1996)                                  NaN     NaN     NaN
# 101 Dalmatians (One Hundred and One Dalmatians)...     NaN     NaN     3.5
# 12 Angry Men (1957)                                    4.5     5.0     NaN
# ...                                                    ...     ...     ...
# Zoolander (2001)                                       NaN     NaN     NaN
# Zootopia (2016)                                        NaN     NaN     NaN
# eXistenZ (1999)                                        NaN     NaN     NaN
# xXx (2002)                                             NaN     NaN     NaN
# ¡Three Amigos! (1986)                                  3.0     3.0     NaN
#
# userId                                              56      71      73      \
# title
# (500) Days of Summer (2009)                            NaN     2.5     4.5
# 10 Things I Hate About You (1999)                      NaN     NaN     NaN
# 101 Dalmatians (1996)                                  0.5     NaN     NaN
# 101 Dalmatians (One Hundred and One Dalmatians)...     1.0     NaN     NaN
# 12 Angry Men (1957)                                    4.0     NaN     NaN
# ...                                                    ...     ...     ...
# Zoolander (2001)                                       2.5     NaN     2.5
# Zootopia (2016)                                        NaN     NaN     NaN
# eXistenZ (1999)                                        NaN     NaN     NaN
# xXx (2002)                                             NaN     NaN     NaN
# ¡Three Amigos! (1986)                                  NaN     NaN     NaN
#
# userId                                              79      ...  283153  \
# title                                                       ...
# (500) Days of Summer (2009)                            NaN  ...     NaN
# 10 Things I Hate About You (1999)                      4.0  ...     3.0
# 101 Dalmatians (1996)                                  NaN  ...     NaN
# 101 Dalmatians (One Hundred and One Dalmatians)...     NaN  ...     NaN
# 12 Angry Men (1957)                                    NaN  ...     NaN
# ...                                                    ...  ...     ...
# Zoolander (2001)                                       NaN  ...     3.0
# Zootopia (2016)                                        NaN  ...     NaN
# eXistenZ (1999)                                        NaN  ...     NaN
# xXx (2002)                                             NaN  ...     0.5
# ¡Three Amigos! (1986)                                  NaN  ...     NaN
#
# userId                                              283164  283165  283170  \
# title
# (500) Days of Summer (2009)                            NaN     NaN     4.0
# 10 Things I Hate About You (1999)                      NaN     4.5     NaN
# 101 Dalmatians (1996)                                  NaN     NaN     NaN
# 101 Dalmatians (One Hundred and One Dalmatians)...     NaN     NaN     NaN
# 12 Angry Men (1957)                                    NaN     3.0     NaN
# ...                                                    ...     ...     ...
# Zoolander (2001)                                       NaN     NaN     NaN
# Zootopia (2016)                                        NaN     NaN     NaN
# eXistenZ (1999)                                        NaN     NaN     NaN
# xXx (2002)                                             NaN     NaN     NaN
# ¡Three Amigos! (1986)                                  NaN     NaN     NaN
#
# userId                                              283183  283184  283185  \
# title
# (500) Days of Summer (2009)                            NaN     4.0     NaN
# 10 Things I Hate About You (1999)                      NaN     NaN     NaN
# 101 Dalmatians (1996)                                  NaN     NaN     NaN
# 101 Dalmatians (One Hundred and One Dalmatians)...     NaN     NaN     3.0
# 12 Angry Men (1957)                                    NaN     NaN     NaN
# ...                                                    ...     ...     ...
# Zoolander (2001)                                       NaN     2.0     NaN
# Zootopia (2016)                                        NaN     NaN     NaN
# eXistenZ (1999)                                        NaN     NaN     NaN
# xXx (2002)                                             NaN     NaN     NaN
# ¡Three Amigos! (1986)                                  NaN     NaN     NaN
#
# userId                                              283195  283204  283224
# title
# (500) Days of Summer (2009)                            NaN     NaN     NaN
# 10 Things I Hate About You (1999)                      2.5     NaN     NaN
# 101 Dalmatians (1996)                                  NaN     NaN     NaN
# 101 Dalmatians (One Hundred and One Dalmatians)...     4.5     NaN     NaN
# 12 Angry Men (1957)                                    NaN     NaN     5.0
# ...                                                    ...     ...     ...
# Zoolander (2001)                                       3.5     NaN     NaN
# Zootopia (2016)                                        NaN     NaN     NaN
# eXistenZ (1999)                                        NaN     NaN     NaN
# xXx (2002)                                             NaN     NaN     NaN
# ¡Three Amigos! (1986)                                  4.5     NaN     NaN
#
# [1344 rows x 35289 columns]

# %%
# load Javier's fake user (or your fake user, if you created one)
url = 'https://raw.githubusercontent.com/um-perez-alvaro/Data-Science-Theory/master/Data/fake_user.csv'
user = pd.read_csv(url, index_col='title', squeeze=True)
user
# Out:
# title
# (500) Days of Summer (2009)                              NaN
# 10 Things I Hate About You (1999)                        NaN
# 101 Dalmatians (1996)                                    NaN
# 101 Dalmatians (One Hundred and One Dalmatians) (1961)   NaN
# 12 Angry Men (1957)                                      NaN
#                                                           ..
# Zoolander (2001)                                         NaN
# Zootopia (2016)                                          NaN
# eXistenZ (1999)                                          NaN
# xXx (2002)                                               NaN
# ¡Three Amigos! (1986)                                    NaN
# Name: rating, Length: 1344, dtype: float64

# %%
# append fake user to the ratings matrix
ratings_matrix['user'] = user
ratings_matrix
# Out:
# userId                                                4   19   42   43   51  \
# title
# (500) Days of Summer (2009)                         NaN  NaN  4.0  NaN  NaN
# 10 Things I Hate About You (1999)                   NaN  NaN  NaN  NaN  NaN
# 101 Dalmatians (1996)                               NaN  NaN  4.0  NaN  NaN
# 101 Dalmatians (One Hundred and One Dalmatians)...  NaN  NaN  NaN  NaN  NaN
# 12 Angry Men (1957)                                 1.5  5.0  NaN  4.5  5.0
# ...                                                 ...  ...  ...  ...  ...
# Zoolander (2001)                                    NaN  NaN  NaN  NaN  NaN
# Zootopia (2016)                                     NaN  NaN  NaN  NaN  NaN
# eXistenZ (1999)                                     3.5  NaN  NaN  NaN  NaN
# xXx (2002)                                          3.5  NaN  NaN  NaN  NaN
# ¡Three Amigos! (1986)                               3.0  NaN  NaN  3.0  3.0
#
# userId                                               55   56   71   73   79  \
# title
# (500) Days of Summer (2009)                         NaN  NaN  2.5  4.5  NaN
# 10 Things I Hate About You (1999)                   1.5  NaN  NaN  NaN  4.0
# 101 Dalmatians (1996)                               NaN  0.5  NaN  NaN  NaN
# 101 Dalmatians (One Hundred and One Dalmatians)...  3.5  1.0  NaN  NaN  NaN
# 12 Angry Men (1957)                                 NaN  4.0  NaN  NaN  NaN
# ...                                                 ...  ...  ...  ...  ...
# Zoolander (2001)                                    NaN  2.5  NaN  2.5  NaN
# Zootopia (2016)                                     NaN  NaN  NaN  NaN  NaN
# eXistenZ (1999)                                     NaN  NaN  NaN  NaN  NaN
# xXx (2002)                                          NaN  NaN  NaN  NaN  NaN
# ¡Three Amigos! (1986)                               NaN  NaN  NaN  NaN  NaN
#
# userId                                              ...  283164  283165  \
# title                                               ...
# (500) Days of Summer (2009)                         ...     NaN     NaN
# 10 Things I Hate About You (1999)                   ...     NaN     4.5
# 101 Dalmatians (1996)                               ...     NaN     NaN
# 101 Dalmatians (One Hundred and One Dalmatians)...  ...     NaN     NaN
# 12 Angry Men (1957)                                 ...     NaN     3.0
# ...                                                 ...     ...     ...
# Zoolander (2001)                                    ...     NaN     NaN
# Zootopia (2016)                                     ...     NaN     NaN
# eXistenZ (1999)                                     ...     NaN     NaN
# xXx (2002)                                          ...     NaN     NaN
# ¡Three Amigos! (1986)                               ...     NaN     NaN
#
# userId                                              283170  283183  283184  \
# title
# (500) Days of Summer (2009)                            4.0     NaN     4.0
# 10 Things I Hate About You (1999)                      NaN     NaN     NaN
# 101 Dalmatians (1996)                                  NaN     NaN     NaN
# 101 Dalmatians (One Hundred and One Dalmatians)...     NaN     NaN     NaN
# 12 Angry Men (1957)                                    NaN     NaN     NaN
# ...                                                    ...     ...     ...
# Zoolander (2001)                                       NaN     NaN     2.0
# Zootopia (2016)                                        NaN     NaN     NaN
# eXistenZ (1999)                                        NaN     NaN     NaN
# xXx (2002)                                             NaN     NaN     NaN
# ¡Three Amigos! (1986)                                  NaN     NaN     NaN
#
# userId                                              283185  283195  283204  \
# title
# (500) Days of Summer (2009)                            NaN     NaN     NaN
# 10 Things I Hate About You (1999)                      NaN     2.5     NaN
# 101 Dalmatians (1996)                                  NaN     NaN     NaN
# 101 Dalmatians (One Hundred and One Dalmatians)...     3.0     4.5     NaN
# 12 Angry Men (1957)                                    NaN     NaN     NaN
# ...                                                    ...     ...     ...
# Zoolander (2001)                                       NaN     3.5     NaN
# Zootopia (2016)                                        NaN     NaN     NaN
# eXistenZ (1999)                                        NaN     NaN     NaN
# xXx (2002)                                             NaN     NaN     NaN
# ¡Three Amigos! (1986)                                  NaN     4.5     NaN
#
# userId                                              283224  user
# title
# (500) Days of Summer (2009)                            NaN   NaN
# 10 Things I Hate About You (1999)                      NaN   NaN
# 101 Dalmatians (1996)                                  NaN   NaN
# 101 Dalmatians (One Hundred and One Dalmatians)...     NaN   NaN
# 12 Angry Men (1957)                                    5.0   NaN
# ...                                                    ...   ...
# Zoolander (2001)                                       NaN   NaN
# Zootopia (2016)                                        NaN   NaN
# eXistenZ (1999)                                        NaN   NaN
# xXx (2002)                                             NaN   NaN
# ¡Three Amigos! (1986)                                  NaN   NaN
#
# [1344 rows x 35290 columns]

# %%
R = ratings_matrix.to_numpy()

# %%
U, V, mean_error = latent_factor_model(R, 
                                       k = 20, 
                                       learning_rate = .00005, 
                                       n_epochs = 50)

# %%
plt.plot(mean_error)

# %%
# predictions
R_pred = U.dot(V.T)
user_pred = pd.Series(R_pred[:,-1], index=fake_user.index) 
user_pred
# Out:
# title
# (500) Days of Summer (2009)                               2.941457
# 10 Things I Hate About You (1999)                         2.723492
# 101 Dalmatians (1996)                                     2.170317
# 101 Dalmatians (One Hundred and One Dalmatians) (1961)    2.653912
# 12 Angry Men (1957)                                       3.398872
#                                                             ...
# Zoolander (2001)                                          2.550660
# Zootopia (2016)                                           3.018559
# eXistenZ (1999)                                           2.664608
# xXx (2002)                                                2.217636
# ¡Three Amigos! (1986)                                     2.413968
# Length: 1344, dtype: float64

# %%
# top 20 predictions
user_pred[user.isna()].sort_values(ascending=False).head(20)
# Out:
# title
# 12 Angry Men (1957)                                                               3.398872
# Rear Window (1954)                                                                3.378847
# Third Man, The (1949)                                                             3.377048
# Usual Suspects, The (1995)                                                        3.375220
# Seven Samurai (Shichinin no samurai) (1954)                                       3.370283
# Casablanca (1942)                                                                 3.356686
# Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1964)       3.331898
# Lives of Others, The (Das leben der Anderen) (2006)                               3.329909
# One Flew Over the Cuckoo's Nest (1975)                                            3.323569
# North by Northwest (1959)                                                         3.319229
# Memento (2000)                                                                    3.297194
# Star Wars: Episode V - The Empire Strikes Back (1980)                             3.294736
# Cinema Paradiso (Nuovo cinema Paradiso) (1989)                                    3.294235
# Ran (1985)                                                                        3.293450
# Chinatown (1974)                                                                  3.289730
# Raiders of the Lost Ark (Indiana Jones and the Raiders of the Lost Ark) (1981)    3.288923
# Big Sleep, The (1946)                                                             3.286813
# Inception (2010)                                                                  3.284147
# Maltese Falcon, The (1941)                                                        3.283270
# City of God (Cidade de Deus) (2002)                                               3.282574
# dtype: float64

# %%
# bottom 20 predictions
user_pred[user.isna()].sort_values().head(20)
# Out:
# title
# Barb Wire (1996)                                1.376297
# Speed 2: Cruise Control (1997)                  1.458129
# Anaconda (1997)                                 1.500546
# RoboCop 3 (1993)                                1.519196
# Super Mario Bros. (1993)                        1.573463
# I Still Know What You Did Last Summer (1998)    1.574734
# Beverly Hillbillies, The (1993)                 1.631965
# Batman & Robin (1997)                           1.664048
# Bio-Dome (1996)                                 1.671118
# Richie Rich (1994)                              1.695663
# Striptease (1996)                               1.700537
# Honey, I Blew Up the Kid (1992)                 1.708311
# Haunting, The (1999)                            1.765118
# Scary Movie 2 (2001)                            1.765805
# Flintstones, The (1994)                         1.787448
# Superman III (1983)                             1.796162
# Juror, The (1996)                               1.802109
# Sliver (1993)                                   1.813186
# Congo (1995)                                    1.822108
# Milk Money (1994)                               1.849557
# dtype: float64

# %% [markdown]
# ## 2. Incorporating user and item biases

# %%
def latent_factor_model(R, k, learning_rate, n_epochs):
    m, n = R.shape
    
    # number of nonzero ratings
    n_zero_ratings = np.sum(~np.isnan(R))
    
    # initialization
    U = np.random.randn(m,k+2)
    U[:,k+1] = 1 # set (k+2)th column to 1
    V = np.random.randn(n,k+2)
    V[:,k] = 1 # set (k+1)th column to 1
    
    mean_error = np.zeros(n_epochs)
    
    # gradient descent steps
    for i in range(n_epochs):
        
        # error matrix
        E = R-U.dot(V.T)
        E[np.isnan(E)]=0

        # update U and V
        new_U = U + learning_rate*E.dot(V)
        new_U[:,k+1] = 1
        new_V = V + learning_rate*E.T.dot(U)
        new_V[:,k] = 1

        U = new_U
        V = new_V
        
        # compute mean_error
        error_squared = np.sum(E**2)
        mean_error[i] = np.sqrt(error_squared/(n_zero_ratings))
        
    return U, V, mean_error

# %% [markdown]
# **MovieLens dataset example**

# %%
U, V, mean_error = latent_factor_model(R, 
                                       k = 10, 
                                       learning_rate = .00001, 
                                       n_epochs = 50)

# %%
plt.plot(mean_error)

# %%
# predictions
R_pred = U.dot(V.T)
fake_user_pred = pd.Series(R_pred[-1], index=fake_user.index) #

# %%
# top 20 predictions
fake_user_pred[fake_user.isna()].sort_values(ascending=False).head(20)
# Out:
# title
# Up Close and Personal (1996)                                                      5.254941
# Short Cuts (1993)                                                                 5.247731
# Good bye, Lenin! (2003)                                                           5.237452
# Three Colors: Blue (Trois couleurs: Bleu) (1993)                                  5.213888
# Secrets & Lies (1996)                                                             5.173924
# On the Waterfront (1954)                                                          5.039088
# Rear Window (1954)                                                                5.036045
# Usual Suspects, The (1995)                                                        5.034747
# Dog Day Afternoon (1975)                                                          5.034643
# Seven Samurai (Shichinin no samurai) (1954)                                       5.020487
# Let the Right One In (Låt den rätte komma in) (2008)                              5.008974
# Casablanca (1942)                                                                 4.992702
# Sgt. Bilko (1996)                                                                 4.988846
# Double Indemnity (1944)                                                           4.988292
# Zootopia (2016)                                                                   4.985629
# One Flew Over the Cuckoo's Nest (1975)                                            4.981909
# North by Northwest (1959)                                                         4.967643
# 12 Angry Men (1957)                                                               4.956673
# Raiders of the Lost Ark (Indiana Jones and the Raiders of the Lost Ark) (1981)    4.951847
# Cool Hand Luke (1967)                                                             4.931992
# dtype: float64

# %%
# bottom 20 predictions
fake_user_pred[fake_user.isna()].sort_values().head(20)
# Out:
# title
# Murder in the First (1995)                                 0.473117
# RoboCop 3 (1993)                                           0.795921
# Juror, The (1996)                                          1.066006
# To Wong Foo, Thanks for Everything! Julie Newmar (1995)    1.091387
# Immortal Beloved (1994)                                    1.234337
# Nixon (1995)                                               1.460415
# Forget Paris (1995)                                        1.520964
# Super Mario Bros. (1993)                                   1.555458
# Bio-Dome (1996)                                            1.722622
# Spy Hard (1996)                                            1.723941
# George of the Jungle (1997)                                1.923108
# Weekend at Bernie's (1989)                                 1.938816
# Indian in the Cupboard, The (1995)                         1.948313
# Sliver (1993)                                              2.121541
# 28 Days (2000)                                             2.143576
# Scream 3 (2000)                                            2.246880
# Charlie's Angels: Full Throttle (2003)                     2.275159
# Superman III (1983)                                        2.360947
# Wedding Planner, The (2001)                                2.365738
# Tank Girl (1995)                                           2.377771
# dtype: float64
